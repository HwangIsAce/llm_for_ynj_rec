# %% [markdown]
# # tourapi

# %%
## leisuresports

# %%
import pandas as pd
tourapi = pd.read_excel('/home/hwang/projects/yanolja/data/dataset/tourAPI/leisureSports.xls')

# %%
tourapi['source'] = 'tourAPI'

# %%
tourapi['category'] = "leisure_sports"

# %%
tourapi.head(2)
# Out:
#                         명칭     우편번호  관리자 전화번호                            주소  \
# 0       [인천 개항 누리길] 2시간 코스  22314.0  NaN  NaN  인천광역시 중구 제물량로218번길 3 (해안동1가)
# 1  [강화 나들길 제3코스] 고려왕릉 가는 길  23033.0  NaN  NaN         인천광역시 강화군 강화읍 청하동길 24
#
#           위도          경도                                                 개요  \
# 0  37.472606  126.620501  인천역 부근 개항장 일대에 조성된 인천 개항 누리길은 근대 개항기 역사와 문화를 체...
# 1  37.745825  126.482261  강화나들길은 해안을 따라 1.3km마다 자리한 돈대와 강화산성, 고려왕릉을 돌며 강...
#
#   문의 및 안내   규모  ...  입장료                                             체험가능연령  \
# 0     NaN  NaN  ...   무료  ＊문화관광해설사(10명 이상, 사전 예약)<br />\n인천문화관광해설사회 예약문의...
# 1     NaN  NaN  ...  NaN                                                NaN
#
#   주차시설 주차요금 유모차 대여 여부 애완동물 동반 가능 여부 신용카드 가능 여부  \
# 0  NaN   가능        없음           NaN         없음
# 1  NaN   있음        없음           NaN         없음
#
#                                                 상세정보   source        category
# 0                                                NaN  tourAPI  leisure_sports
# 1  코스안내:[강화 나들길 제3코스] 고려왕릉 가는 길<br />\n* 온수공영주차장-...  tourAPI  leisure_sports
#
# [2 rows x 24 columns]

# %%
tourapi.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '문의 및 안내', '규모',
#        '수용인원', '쉬는날', '개장기간', '이용시간', '입장료', '체험가능연령', '주차시설', '주차요금',
#        '유모차 대여 여부', '애완동물 동반 가능 여부', '신용카드 가능 여부', '상세정보', 'source',
#        'category'],
#       dtype='object')

# %%
tourapi.rename(columns= {'명칭': 'place_name', 
                                   '주소':'address', 
                                   '위도': 'latitude', 
                                   '경도': 'longitude', 
                                   '이용시간': 'available_time', 
                                   '주차시설': 'parking', 
                                   '개요': 'description', 
                                   '우편번호': 'zip_code', ## 
                                   '관리자': 'manager',
                                   '전화번호': 'phone',
                                   '문의 및 안내': 'guidance',
                                   '규모': 'scale',
                                   '수용인원': 'capacity',
                                   '쉬는날': 'day_off',
                                   '입장료': 'fee', 
                                   '주차요금': 'parking_fee', 
                                   '체험가능연령': 'age_available',
                                   '개장기간': 'opening_period',
                                   '유모차 대여 여부': 'stroller',
                                   '애완동물 동반 가능 여부': 'pet',
                                   '신용카드 가능 여부': 'credit_card',
                                   '상세정보': 'details'}, inplace=True)

tourapi = tourapi[['source', 'category', 'place_name', 'address', 'latitude', 'longitude', 'available_time', 'parking', 'description', 'zip_code', 'manager', 'phone', 'guidance', 'scale', 'capacity', 'day_off', 
                            'fee', 'parking_fee', 'age_available', 'opening_period', 'stroller', 'pet', 'credit_card', 'details']]

# %%
tourapi.isnull().sum() / len(tourapi)
# Out:
# source            0.000000
# category          0.000000
# place_name        0.000000
# address           0.000215
# latitude          0.000000
# longitude         0.000000
# available_time    0.173726
# parking           0.918727
# description       0.001505
# zip_code          0.034401
# manager           0.878521
# phone             0.917652
# guidance          0.997205
# scale             0.938078
# capacity          0.949903
# day_off           0.413244
# fee               0.956138
# parking_fee       0.176306
# age_available     0.452161
# opening_period    0.525693
# stroller          0.171361
# pet               0.560310
# credit_card       0.145345
# details           0.062567
# dtype: float64

# %%
tourapi.isnull().sum()
# Out:
# source               0
# category             0
# place_name           0
# address              1
# latitude             0
# longitude            0
# available_time     808
# parking           4273
# description          7
# zip_code           160
# manager           4086
# phone             4268
# guidance          4638
# scale             4363
# capacity          4418
# day_off           1922
# fee               4447
# parking_fee        820
# age_available     2103
# opening_period    2445
# stroller           797
# pet               2606
# credit_card        676
# details            291
# dtype: int64

# %%
list(set(tourapi['available_time']))
# Out:
# ['09:00~17:30 (브레이크타임 13:00~13:30)',
#  '14:00 ~ 12:00(익일)',
#  '09:00~21:00<br>※ 계절별, 날씨 상황에 따라 영업시간 변동',
#  '1박시 13시~익일 11시',
#  '하절기 (6월~8월) 09:00~18:00',
#  '09:00~18:00<br>※ 이용시간은 변동될 수 있으므로<br>홈페이지 참조 또는 전화 문의 요망',
#  '평일 09:00~18:00  주말 09:00~18:00',
#  '평일 예약제 / 주말 11:00~17:00 (이용시간 변동있을 수 있음)',
#  '입실 13:00~19:00 / 퇴실 익일 11:00까지',
#  '13:30 ~ 익일 13:00',
#  '[3월~10월] 09:30~17:00<br>[11월~2월] 09:30~16:00',
#  '일출부터 일몰때까지 (남코스 9Hole Light 시설)',
#  '입실 15:00 / 퇴실 11:00',
#  '10:00 ~ 18:00 (16:00 마지막 체험 시작)',
#  '당일 오후 14시~익일 오후 12시',
#  '하절기(4월~10월)<br>- 09:00~17:30<br>- 매표마감 16:30<br>동절기(11월~3월) <br>- 09:00~16:30<br>- 매표마감 15:30<br>※ 기상상황에 따라 개/폐장 여부가 변경될 수 있음',
#  '업체마다 상이',
#  '요일, 날짜, 계절에 따라 상이 (홈페이지 또는 예약실로 확인)',
#  '00:00~23:59',
#  '캠핑장 <br> 체크인 14:00~체크아웃11:00<br>매너타임 22:00 ~ 08:00',
#  '10:00~17:00(매표마감 16:00 / 정설시간 12:00~13:00)',
#  '09:00~18:00<br>평일 휴게시간 12:00~13:00<br>접수 마감 17:00<br>※포레스트 어드벤처, GPR 서바이벌(3월~11월 )',
#  '주중 08:00 ~ 24:00 <br>주말 08:00 ~ 22:00',
#  '입실 14:00<br/>\n퇴실 13:00',
#  '월~금 12:00~23:00 / 토 10:00~23:00 / 일 10:00~21:00',
#  '입실 - 15:00<br>퇴실 - 익일 11:00<br>※ 조기 입실 및 지연 퇴실 시 추가 요금 발생<br>※ 퇴실 시 관리 사무실 연락 및 퇴실 점검 후 퇴실',
#  '예약 시간에 따라 상이함',
#  '화~금 12:00~21:00 / 토, 일 09:00~21:00',
#  '11:00~22:00',
#  '전화문의',
#  '09:00~18:00 (12:00~14:00 휴게시간)',
#  '[주중]<br>- 3월~11월 : 06:00~23:00<br>- 12월~2월 : 06:00~22:00<br>[주말,공휴일]<br>- 3월~11월 : 06:00~22:00<br>- 12월~2월 : 06:00~21:00',
#  '일출 20분 전 ~ 일몰 20분 후까지',
#  '[오토캠핑장] 입실 13:00 ~ 퇴실 11:00<br>[숙박시설(캐라반)] 입실 14:00~ 퇴실 11:00',
#  '14:00 - 익일 11:00',
#  '하계(2월~11월) 08:00~18:00<br />동계(12월~1월) 08:00~17:00',
#  '09:00~18:00',
#  '하절기 09:00~18:00 / 동절기 09:00~17:00',
#  '매일 기상 상황에 따라 변동됨',
#  '평일 10:00~17:00 / 토요일 10:00~19:00 / 일요일 10:00~18:00',
#  '[캠핑장]<br>입촌 - 13:00<br>퇴촌 - 익일12:00<br>[글램핑장]<br>입실 - 15:00<br>퇴실 - 익일 11:00',
#  '- 주중 09:00~18:00 (브레이크타임 12:30~13:30)<br>- 토요일, 공휴일 08:30~18:30 (브레이크타임 12:30~13:30)<br>- 일요일 08:30~18:00 (브레이크타임 12:30~13:30)',
#  '하절기 : 04:30~22:00<br>동절기 : 05:00~21:00',
#  '입실 14:00 입실 /  퇴실 13:00 <br>※ 입장 마감 21:00',
#  '예약시 문의',
#  '[캠핑]<br>- 14:00 ~ 익일 11:00<br>[펜션, 카라반]<br>- 15:00 ~ 익일 11:00',
#  '11:00 ~ 익일14:00',
#  '10:00~21:00',
#  '15:00~익일 10:30',
#  '상시개방(자유탐방로)',
#  '월요일~금요일 10:00~20:00 / 주말 및 공휴일 10:00~21:00',
#  '업체별 상이',
#  '10:00~18:00 (브레이크타임 12:00~13:00)',
#  '15:00~익일11:00',
#  '물놀이터 09:30~18:00 <br>숙박시설 15:00~익일 11:00',
#  '- 월요일~토요일 06:00~22:00<br>- 공휴일 06:00~20:30',
#  '15:00~익익 11:00',
#  '캠핑 13:00~익일11:00<br>펜션 14:00~익일11:00',
#  '하절기 09:00 ~ 17:00<br>동절기 09:00 ~ 15:30<br>※ 하절기 출발 : 09:00 / 10:30 / 12:00 / 14:00 / 15:30 / 17:00<br>※ 동절기 출발 : 09:00 / 10:30 / 12:00 / 14:00 / 15:30',
#  '00:00~24:00',
#  '매일 06:00 - 24:00',
#  '9:00~18:00 (17:00 입장 마감)<br>12:00~14:00 (점심시간)',
#  '03~10월(하절기) 10:00~18:00<br> [마지막 탑승가능시간:17시30분]<br>11~2월(동절기) 10:00~17:00<br>[마지막 탑승가능시간:16시50분]<br>※ 정비시간 12:00~12:45/15:00~15:30',
#  '솔숲텐트사이트 / 오토캠핑사이트 14:00~익일 13:00<br>카라반 / 펜션형 15:00~익일 11:00',
#  '자동차·카라반 야영지 14:00~익일12:00<br>카라반·하우스 15:00~익일11:00',
#  '오전 11:30- 오후 04:00<br>오후 05:00- 오후 09:00',
#  '하절기(3~10월) 09:00~17:50 <br />\n동절기(11~2월) 09:00~17:00',
#  '입실 15:00<br>퇴실 익일 11:00',
#  '오토캠핑 14:00 ~ 익일 11:00 <br>글램핑, 펜션 15:00 ~ 익일 11:00',
#  '- 캠핑 14:00~익일 12:00<br>- 펜션/글램핑 15:00~익일 11:00',
#  '입실 - 14:00<br>퇴실 - 익일11:00',
#  '15:00~익일10:00',
#  '입실 15:00<br>퇴실 11:00<br>※ 22시 이후 체크인 시 사전 연락 필수',
#  '[일요일~금요일]<br>10:00~18:00<br>[토요일 및 하계성수기]<br>10:00~21:00',
#  '15:00  ~ 익일 12:00',
#  '입실 14:00, 퇴실 13:00',
#  '기상상황에 따라 상이',
#  '패키지마다 상이하므로 홈페이지 참조 및 전화 문의 요망',
#  '05:00 ~ 20:00',
#  '09:00 ~ 17:30 (전화문의 요망)',
#  '09:00~24:00',
#  '[캠핑] 14:00~익일11:00<br>[글램핑] 15:00~익일11:00',
#  '경기 일정에 따라 상이함',
#  '- 동절기(11월 ~2월): 09:00 ~ 17:00<br>- 하절기(3월 ~ 10월): 09:00 ~ 18:00<br>※ 자세한 이용시간은 전화문의 요망',
#  '[하절기 3월~10월]<br>- 평일 06:00~22:00 / 토요일 06:00~18:00 / 일요일 및 공휴일 09:00~17:00<br><br>[동절기 (11월~2월)]<br>- 평일 06:00~21:30 / 토요일 06:00~18:00 / 일요일 및 공휴일 09:00~17:00',
#  '평일 10:00~23:00<br> 토요일 10:00~20:00',
#  '1회 : 10:00<br />\n2회 : 11:00<br />\n3회 : 13:00<br />\n4회 : 14:00<br />\n5회 : 15:00<br />\n6회 : 16:00<br />\n7회 : 17:00',
#  '13:00~익일 13:00이전',
#  '09:00~18:00(휴게시간 11:30~12:30)',
#  '12:00 ~ 익일10:00',
#  '10:00~17:00 (여름 10:00~18:00)',
#  '10:00~22:00  탑승 10분전 도착',
#  '월요일~금요일 05:50~22:00<br> 토요일 09:00~16:40<br> 일요일 10:00~16:40',
#  '08:00-23:00',
#  '자동차 야영지 14:00~익일12:00<br>하우스 15:00~익일11:00',
#  '07:30~23:00',
#  '3월~11월 09:00~17:00<br>12월~2월 09:00~16:00',
#  '※ 입장관련 시간은 홈페이지 참조요망',
#  '08:00 - 18:00',
#  '14:00~익일12:00',
#  '06:00~23:00 (동절기는 단축 운영)',
#  '평일 12:30~21:00 / 주말, 여름철 10:00~21:00',
#  '평일 14:00 ~ 익일 11:00 / 주말 15:00 ~ 익일 11:00   / 오토캠핑 13:00 ~ 익일 12:30',
#  '09:00~23:59',
#  '09:00~16:30 <br>-계절별 운영시간 상이, 업체 연락 후 방문 요망',
#  '15:00~익일 11:00',
#  '화~금 10:00~18:00 (시설점검 12:30~13:30) <br>토,일,공휴일 09:00~18:00(시설점검 12:30~13:30)<br>※ 휴게시간&운영종료시간 10분전 탑승마감',
#  '상시  개방',
#  '12:00 ~ 익일11:00',
#  '10:00~17:00 (기온, 날씨에 따라 변동 가능)',
#  '07:00~23:00(평일), 07:00~24:00(금,토,일, 공휴일)',
#  '09:30~18:00 (점심시간 13:00 ~ 14:00)',
#  '정해져 있지 않음(원하는 시간에 이용가능)',
#  '[ 평일 ] 10:00~23:00 / [ 주말 / 공휴일 ] 10:00~20:00',
#  '[카라반]<br>-입실 15:00 / 퇴실 익일11:00<br><br>[데크]<br>-입실 13:00 / 퇴실 익일 11:00',
#  '- 걷기 시작시간 09:00<br />- 걷기 종료시간 18:00 (하절기) / 17:00 (동절기)',
#  '09:00~20:00(18:00 이후 예약 필수)<br>12:00~13:30 휴게시간',
#  '에약 시 문의',
#  '[캠핑]<br>14:00~익일 12:00<br>[글램핑]<br>15:00~익일 11:00<br>[펜션]<br>15:00~익일 11:00',
#  '14:00-익일 12:00',
#  '출항 : 04:30~05:00 <br>입항 : 16:00~17:00',
#  '평일 13:00~21:00 <br>주말 및 공휴일 11:00 ~ 21:00',
#  '홈페이지 및 전화 문의',
#  '10:00 ~ 22:00',
#  '캠핑 13:00~익일12:00<br>펜션 15:00~익일11:00',
#  '평일 06:00~22:00 (프로그램,시설별 상이)',
#  '09:00~ 21:00',
#  '좌대 입장시간 14:00 ~ 22:00',
#  '홈페이지 참조',
#  '09:00~18:00<br>※일몰 시간에 따라 변동있음',
#  '07:00~01:00',
#  '10:00~18:30 (12:00~13:00 휴게시간) <br>- 발권 및 입장 마감 18:00',
#  '* 성수기(6~9월) / 비수기 주말 / 공휴일 : 09:00~21:00 * 비수기 주중(10월~5월) : 09:00~20:00',
#  '07:00~22:00',
#  '08:00~17:30분(휴게시간 12:00~13:00)',
#  '14:00~익일 12:00',
#  '09:00~18:00 (휴게시간 12:00 ~ 14:00)',
#  '캠핑 13:00 ~ 익일11:00<br>카라반 15:00 ~ 익일11:00',
#  '하계 05:00~22:00<br>동계 07:00~20:00',
#  '09:00~18:00(휴게시간 : 12:00~13:00 / 장비점검 : 15:00~16:00)',
#  '시설별 상이하므로 홈페이지 참조',
#  '06:00~20:00<br>※ 3월~11월 휴무',
#  '동절기(12월 ~ 3월) 09:00~16:00 <br>하절기(4월 ~ 11월) 08:00~18:00<br>※ 풍속, 강우, 강설 등 기상상황에 따라 변동가능성 있음',
#  '평일 06:00~21:00<br>주말 06:00~17:00',
#  '주중 06:00 - 21:00<br>주말 06:00 - 16:50<br>',
#  '- 평일 14:10~18:00<br />\n- 주말 12:10~18:00<br />\n※ 방학기간 일정은 홈페이지 참조',
#  '선착순입장',
#  '평일 11:00~21:00 / 주말, 공휴일, 방학 10:00~21:00',
#  '일출부터 일몰까지<br>※ 자세한 이용시간은 홈페이지 참조',
#  '09:00 ~ 18:00 (계절별로 상이함)',
#  '운영 시간은 클럽 상황에 따라 조정',
#  '리프트 / 슬로프<br>주중, 공휴일 전일 : 09:00~02:00<br>주말 및 공휴일 : 09:00~02:00<br>주중 심야 할인 : 18:00~02:00',
#  '* 평일(월~금) 10:00~17:40<6타임><br />* 주말(토,일)/공휴일 10:00~20:20 8타임><br />※ 전화문의',
#  '입실 13:00 ~ 퇴실 12:00',
#  '평일 12:00~23:00<br>주말, 공휴일 10:00~19:00',
#  '12:00~익일 11:00',
#  '평일 09:00~20:00 <br />주말 09:00~18:00',
#  '06:00 ~ 19:00',
#  '입실시간 14:00 <br/>\n퇴실시간 13:00',
#  '07:30~18:00',
#  '07:30~20:00',
#  '2부제로 운영(06:30~19:00)',
#  '화~일 09:00~18:00',
#  '13:00 ~20:00',
#  '입실 11:00<br>퇴실 익일13:00<br>※ 연휴기간은 퇴실 익일12:00까지',
#  '[오토캠핑&글램핑존]<br> - 입실 13:00 / 퇴실 익일 11:00<br> [펜션]<br> - 입실 15:00 / 퇴실 익일 11:00<br> * 매너타임 22:00 이후',
#  '입실 - 14:00~21:00(동절기 20:00)<br>퇴실 - 익일 11:00 이전',
#  '09:00~18:00 (매표는 17:00 마감)',
#  '14:00~퇴실 11:00',
#  '10:00~17:00 (휴게시간 12:00~13:00)',
#  '주중 10:00~19:00<br>토요일 10:00~20:00<br>일요일 10:00~20:00  <br>※루지 / 하이플라이 티켓 발권 마감 시간 운영 마감 30분 전',
#  '평상(7월~8월) 09:00~17:30<br>평상(9월~6월) 09:00~17:00<br>캠핑 13:00~익일 11:00',
#  '개장시간  : 일출시간 1시간 전',
#  '* 걷기 시작시간 09:00<br />\n* 걷기 종료시간 18:00(하절기) / 17:00(동절기)',
#  '09:00~20:30',
#  '14:00 ~ 12:00 (익일) - 오토캠핑존',
#  '09:00~18:00(라스트오더 16:00)',
#  '평일 06:00~22:30<br />토요일 06:00~20:00<br />공휴일 09:00~18:00',
#  '10:00 ~ 21:00',
#  '08:00 ~ 24:00',
#  '15:00~익일 13:00',
#  '[카라반]<br>- 15:00 ~ 익일 11:00 <br>[캠핑데크]<br>- 14:00 ~ 익일 13:00<br>[학교방 숙박]<br>- 15:00 ~ 익일 11:00',
#  '06:00~20:00',
#  '평일  09:00~19:00<br>주말 09:00~20:00',
#  '09:30~18:00',
#  '오토캠핑 13:00~익일 12:00<br>글램핑 12:00~익일 11:00<br>매너타임 22:00~08:00',
#  '평일 06:00~22:00 / 토요일 06:00~18:00 / 일요일 09:00~18:00',
#  '11:00~익일 11:00',
#  '14:00 ~ 익일 11:00<br>※ 자세한 안내는 홈페이지 참조',
#  '월요일~금요일 06:00~23:00<br>토요일 06:00~21:00<br>공휴일 09:00~18:00',
#  '10:00 ~ 18:00 (계절별 마감시간 상이함 / 일몰 30분 전)',
#  '평일 : 07:00~11:00, 주말/공휴일 24시간 운영',
#  '14:00 ~ 익일13:00',
#  '일출 ~ 일몰시까지',
#  '캠핑 15:00 ~ 익일11:00<br>펜션 14:00 ~ 익일12:00',
#  '[근현대사 기념관] 화요일~일요일 09:00~18:00',
#  '주간 09:00~17:00(퇴장시간 17:30)<br> 야간 18:00~22:00(퇴장시간 22:30)<br> *야간개장은 별도 공지',
#  '※ 계절마다 시간이 상이함(홈페이지 참조)',
#  '입실 14:00 / 퇴실 13:00',
#  '상시 10:00~18:00',
#  '캠핑 13:00 ~ 익일 12:00 <br>펜션 14:00 ~ 익일 12:00',
#  '평일 08:00~22:00 / 토요일 09:00~18:00',
#  '매월변동',
#  '[글램핑]<br>- 15:00 ~ 익일 11:00<br>[오토캠핑]<br>- 14:00 ~ 익일 12:00',
#  '주중 09:00 ~ 17:20<br>주말 09:00 ~ 18:00',
#  '05:30~21:00',
#  '[수상레저]<br/>\n09:00~19:00 (동절기 미운영)<br/> \n[워터파크]<br/>\n09:00~18:00<br/>\n[객실]<br/>\n입실 15:00/퇴실 11:00<br/>\n※ 자세한 사항은 홈페이지 참조',
#  '09:00~21:00',
#  '12:30 ~ 익일 13:00',
#  '주중(월~금) 10:30~18:00(입장마감 17:00)<br>주말 및 공휴일 10:30~20:30(입장마감 19:30)',
#  '12:00~익일 13:00',
#  '< 하절기(6월말 ~8월 중순) ><br> 10:00~17:00<br> < 동절기(12월 중순~2월 중순) ><br> 10:00~17:00',
#  '- 카라반 15:00~익일 11:00<br>- 카라반 외 14:00~익일 12:00',
#  '13:00~익일12:00',
#  '13:00~익일 12:00 (연휴 및 토요일 기준)',
#  '주중 09:00~17:00<br>주말 09:00~18:00',
#  '월요일~토요일 09:00~21:00<br>일요일 09:00~18:00<br>※ 자세한 이용시간은 홈페이지 참조',
#  '24시간 (영업장 사정상 변동 가능)',
#  '06:00~20:30',
#  '평일 10:00~18:00,  주말/공휴일 09:00~19:30',
#  '11:00~익일11:00',
#  '09:00~익일08:00',
#  '매일 08:00~19:00',
#  '[입실]15:00~ (22:00이후 체크인 시 사전문의 필수)<br>[퇴실] 익일 11:00',
#  '화~금요일 10:00~21:00 <br />토~일요일 및 공휴일 09:00~18:00',
#  '물놀이(평일) 09:00~18:00<br>강습&자유(평일) 06:00~21:00<br>주말&공휴일 08:00~17:00<br><br>※ 자유수영 이용 불가 시간<br>- 월, 수, 금요일 : 07:00, 08:00, 10:00, 15:00, 16:00, 19:00, 20:00<br>- 화, 목요일 : 06:00, 07:00, 08:00, 10:00',
#  '주중 12:00~19:00<br>주말 12:00~20:00 <br>※주말, 공휴일은 이용 시간 3시간으로 제한',
#  '시즌별로 다르므로 홈페이지 또는 예약실 문의',
#  '09:00 ~ 18:00',
#  '월~금 : 11:00~20:00 <br>토 : 08:00~17:00',
#  '-평일 06:00 ~ 22:00<br>-주말 및 공휴일 06:00 ~ 20:00',
#  '18홀 라운딩 소요 시간 4시간 30분',
#  '입실 14:00<br/>퇴실 11:00',
#  '하절기(3~11월) 08:00~12:00 / 14:00~18:00 <br>동절기(12~2월) 09:00~12:00 / 14:00~17:00',
#  '09:00~19:00 (일몰 시간 까지)',
#  '10:00 ~ 익일 12:00 <br>\n(연휴기간 12:00 ~익일 12:00)',
#  '06:00~21:00 (날씨 및 계절에 따른 변경은 예약 시 확인)',
#  '[C,E구역(일반(대형)야영지, 캠핑용자동차전용야영지)]<br>- 14:00 ~ 익일 12:00<br>[A,B,E구역(하우스, 카라반)] <br>- 15:00 ~ 익일 11:00',
#  '문의 후 협의',
#  '10:00 ~ 18:00<br>방문 전 통제구간 확인 요망',
#  '입실 14:00/퇴실 11:00',
#  '주중 09:00 ~ 16:00<br>주말 08:00 ~ 17:00',
#  '- 평일 10:00~21:00<br>- 주말 09:00~19:00<br>(주말 휴게시간 13:00~14:00 / 16:00~17:00)',
#  '09:00~18:00 (휴게시간 12:00~13:30)',
#  '주중 10:00 ~ 18:00 <br>주말(토, 일, 공휴일) 09:00 ~ 18:00',
#  '프로그램에 따라 상이',
#  '09:00~21:30',
#  '글램핑 16:00~익일13:00',
#  '[캠핑]<br>12:00~익일 12:00<br>[글램핑]<br>14:00~익일 11:00',
#  '[개장] 09:00~18:00<br>[숙박] 15:00~익일 11시',
#  '월~토 05:30 ~ 20:30<br />\n일요일 및 공휴일 07:00 ~ 18:00 <br />\n* 정화시간 8:00 ~ 9:00, 12:00 ~ 13:00, 16:00 ~ 17:00(여름성수기) 이용 제한',
#  '캠핑장 13:00 ~ 익일 12:00<br>펜션 15:00 ~ 익일 11:00',
#  '14:00~익일 10:00 (22:00 입장 마감)',
#  '매일 06:00~22:00',
#  '05:00~21:00',
#  '펜션 15:00~익일 11:00<br>캠핑 14:00~익일 12:00<br>글램핑 15:00~익일 11:00',
#  '3월~10월 09:30~20:00 (18:50 발권 마감)<br>11월~2월 09:30~18:30 (17:20 발권 마감)<br>브레이크타임 12:00~12:30 / 17:00~17:30',
#  '10:00~12:00, 14:00~17:00 <br>※ 여름철 운영시간 변동되므로 전화문의 필수',
#  '글램핑 14:00~익일11:00<br>자가텐트 13:00~익일12:00',
#  '09:00~18:00(동계는 17:00까지, 점심시간 : 12:00~13:00)',
#  '14:00 ~ 익일 11:30',
#  '09:00~21:00 <br>※문자 상담 가능 시간 09:00~22:00',
#  '캠핑장 12:30 ~ 익일 12:00 <br>펜션 13:00 ~ 익일 11:00',
#  '평일 06:00~20:00 / 토요일 06:00~17:00 / 일요일 및 공휴일 10:00~17:00',
#  '※ 비진도 선박운항(통영항) 요금 대인 9,640원<br>07:30 / 11:30 / 15:10',
#  '05:00 ~ 20:30',
#  '06:30~19:00',
#  '06:00~23:00 (기상상황에 따름)',
#  '07:00 ~ 20:00 서핑(강습시간기준)',
#  '09:30~17:30 (기상상황에 따라 변동될 수 있음)',
#  '입실 : 14:00 <br>퇴실 : 11:00',
#  '09:00 ~ 18:00(월~금) / 점심시간 : 12:00~13:00',
#  '13:00 ~ 익일13:00',
#  '10:00~17:00 (점심시간 12:00~13:00)',
#  '07:00~21:00<br>※ 자세한 이용시간은 홈페이지 참조',
#  '이용 대상별 상이',
#  '14:00~익일13:00',
#  '[캠핑장]<br>입실 13:00 ~ 익일 11시<br>[카라반]<br>14:00 ~ 익일 11시',
#  '[평일] 07:00~24:00<br>[주말] 00:00~24:00',
#  '[주중 및 주말]<br>14:00~ 익일 11:00<br>[금요일]<br>17:00~익일 14:00',
#  '- 캠핑장 14:00~익일11:00<br>- 펜션 15:00~익일11:00',
#  '일요일~목요일 07:00~23:00<br>금요일~토요일 07:00~06:50',
#  '월-토 13:30 ~ 21:30<br>일요일 10:00 ~ 21:30',
#  '06:00~23:00',
#  '00:00 ~ 24:00/ 자전거대여 10:00 ~ 19:00',
#  '당일 14:00~익일 13:00<br>※ 카라반 시설은 당일 14:00~익일 11:00',
#  '하절기 09:00~18:00<br>동절기 09:00~17:00',
#  '12:00~익일12:00',
#  '09:00~19:00 (이용시간 사전 문의 필수)',
#  '10:00~17:30 (휴식시간 12:00~13:30)',
#  '입실 - 14:00<br>퇴실 - 익일12:00',
#  '계절 및 날씨에 따라 변동되므로 예약실로 문의',
#  '05:00~20:00<br>이용 시간은 변동될 수 있으므로 홈페이지 참조',
#  '[하절기] 09:00~18:00 <br>[동절기] 10:00~17:00',
#  '[캠핑] 13:00~익일11:00<br>[글램핑] 15:00~익일11:00',
#  '14:00~퇴실 12:00',
#  '07:00 ~21:59',
#  '[캠핑]<br>13:00~익일 11:00<br>[글램핑/펜션]<br>14:00~익일 11:00',
#  '15:00~익일 11:00<br>※ 자세한 이용시간은 홈페이지 참조 및 전화 문의 요망',
#  '16:00~익일 11:00',
#  '[탑랜드]09:10~ 18:00<br>[번지점프]1부 9:00~10:00<br>2부 11:30~17:30',
#  '09:00~17:00 (12:00~14:00 점심시간)<br />19:00~19:50 (화,목 야간승마)',
#  '09:00 ~ 18:00 <br>\n동절기 10:00 ~ 17:00',
#  '16:00~익일 12:00<br>※ 자세한 이용시간은 전화 문의 요망',
#  '11:00~익일15:00',
#  '경기 시간 (상설경기 토요일 13시30분 등)',
#  '[평일] 11:00~23:00 / [ 주말] 10:00~24:00',
#  '12:00 ~ 익일 12:00',
#  '[펜션]<br>15:00~익일 11:00<br>[캠핑, 카라반]<br>14:00~익일 11:00',
#  '[ 월요일~목요일 ] 11:00~22:30 / [ 금요일 ] 17:00~22:30 / [ 주말 ] 13:30~19:00',
#  '10:00~24:00',
#  '입실 14:00<br>퇴실 익일 11:00',
#  '10:00 ~ 16:00 (입장마감 14:00)',
#  '06:00~21:30 (이용시간 변동 가능성 있으므로 전화 문의 바람)',
#  '숙소 입실 14:00 이후, 퇴실 09:00까지',
#  '10:00~익일 15:00',
#  '주중 12:00~22:30 <br>주말 10:00~21:00',
#  '입실 14:00<br>퇴실 11:00<br>매너타임 22:00~07:00',
#  '[수영장]<br>-평일<br>06:00~12:50/14:00~20:50<br>-토요일,일요일 및 공휴일<br>1부 09:00 ~ 12:50/2부 14:00 ~ 16:50<br>[다이빙풀]<br>-평일<br>1부 14:00~16:50/2부 19:00~20:50<br>-토요일,일요일 및 공휴일<br>1부 09:00~11:50/2부 14:00~16:50',
#  '캠핑 14:00~익일13:00<br/>카라반/글램핑 14:00~익일11:00',
#  '[카라반, 야영장]<br>- 14:00 ~ 익일 11:00',
#  '하절기 : 09:00~19:30<br>동절기 : 09:00~17:30',
#  '입실 14:00 ~ 퇴실 13:00',
#  '실내시설 09:00~21:00',
#  '토요일~목요일 10:00~22:00 / 금요일 10:00~23:00',
#  '[스카이라인 루지]<br>주중 10:00~19:00<br>주말 및 공휴일 10:00~20:00<br> ※ 티켓 판매 종료는 운영마감 30분전<br><br>[하이플라이 짚라인]<br>10:00~18:00<br>※ 하이플라이 탑승마감 17:45',
#  '일요일 ~ 목요일 13:00 ~ 20:00<br>금요일, 토요일 13:00 ~ 22:00',
#  '오전 10시 ~ 오후 5시',
#  '입실 15:00 / 퇴실 익일 11:00',
#  '월 13:00~18:00<br>- 휴게시간 15:00~15:20<br>화~일 09:00~18:00<br>- 휴게시간 12:00~13:00/15:00~15:20',
#  '- 산막텐트 15:00~익일11:00<br>- 일반야영지 14:00~익일12:00',
#  '[캐라반 1~14호 (6명)]<br> -14:00~익일 11:00<br />[캐라반 15~22호 (8명) / 캐빈하우스]<br>-15:00~익일 12:00',
#  '- 캠핑 12:00~익일 11:00<br>- 캠프닉 09:00~18:00',
#  '[캠핑]<br>- 14:00~익일 12:00<br>[카라반]<br>- 14:00~익일 11:00',
#  '입실: 12:00~18:00 / 퇴실: 익일 12:00 <br>- 기상악화로 인한 천재지변시 야영장 이용불가',
#  '예약 시 확인',
#  '10:00~17:00<br>※ 휴게시간 11:50~13:00 / 14:50~15:20<br>※ 매표마감 16:00',
#  '10:00 ~ 17:00(11:50~12:30 쉬는시간)',
#  '09:00~20:00 (상담원 채팅 09:00~18:00)',
#  '월~금 06:00 ~ 22:00, 토요일 06:00 ~ 18:00, 일요일(2,4주) 09:00 ~ 18:00',
#  '일출~일몰까지',
#  '입실:13:00 / 퇴실:12:00',
#  '08:00~익일 10:00<br>※ 자세한 이용시간은 전화 문의 요망',
#  '07:00~익일 01:00',
#  '예약 시간에 이용가능',
#  '일출에서 일몰까지',
#  '매일 09:00~18:00',
#  '계절별 상이',
#  '- 평일 : 10:00~17:40 <br>- 주말, 공휴일 : 10:00~18:40',
#  '예약 후, 예약 시간 이용가능',
#  '09:00~익일11:00',
#  '평일 06:00~20:00<br>주말 05:00~20:00',
#  '- 11~2월 09:00~17:00<br>- 3~10월 09:00~18:00',
#  '평상시 (3월~11월)<br>주중 09:00~18:00 주말,공휴일 09:00~19:00<br>동절기 (12월~2월)<br>주중 09:00~17:00 주말, 공휴일 09:00~18:00',
#  '몰운대유원지 이용시간 09:00~18:00',
#  '영업시간 - 11:00~22:00<br> 평일 - 11시부터 시간 단위로 예약가능 / 4시간 이용 가능<br> 주말 - 주말 하루 3타임(11시, 15시, 19시) 운영 / 3시간 이용 가능',
#  '14:00 ~ 익일12:00',
#  '14:00 ~ 익일14:00',
#  '매일 11:00 ~ 20:00',
#  '[캠핑존]<br>13:00 ~ 익일 12:00<br>[펜션]<br>14:00 ~ 익일 11:00',
#  '펜션 14:00~익일11:00<br>캠핑 14:00~익일12:00',
#  '평일 09:30 ~ 17:30 <br />주말, 공휴일 09:00 ~ 18:00<br />야간승마 18:00 ~ 20:00 (화요일,목요일 가능) <br />※ 월 회원은 별도 시간 협의가능',
#  '[ 평일 ] 08:00~08:50<br>[ 주말 ] 10:00~17:30',
#  '예약시 확인 (시간, 날짜별로 다름)',
#  '07:00~23:00',
#  '14:00 ~익일12:00',
#  '매주 토, 일요일 10:00 / 13:00 / 15:30',
#  '캠핑 13:00~익일11:00<br>펜션 15:00~익일11:00',
#  '15:00  ~ 익일 11:00',
#  '※ 예약제 운영',
#  '날짜, 날씨, 계절별로 다름 (예약실로 문의)',
#  '입실 : 13:00 / 퇴실 : 익일11:00',
#  '09:00~18:00<br / >※ 전화문의 요망',
#  '눈썰매장 10:00 ~ 13:00/ 14:00~17:00',
#  '비수기 14:00~익일11:00<br>성수기 15:00~익일11:00',
#  '7층 : 10:00~01:00<br>8층 : 일~목 18:00~02:00 / 금~토 18:00~03:00',
#  '15:00~ 익일11:00',
#  '09:00 ~ 21:00',
#  '* 걷기 시작시간 09:00<br />\n* 걷기 종료시간 18:00(하절기)/17:00(동절기)',
#  '수~금 11:00~20:00<br>주말 및 공휴일 10:00~21:00',
#  '일~목요일 09:00~02:00<br>금~토요일 09:00~04:00',
#  '캠핑 12:00~익일 12:00<br>펜션 15:00~익일 11:00',
#  '걷기 시작시간 09:00<br>걷기 종료시간 18:00(하절기) / 17:00(동절기)',
#  '10:00 ~ 익일 10:00',
#  '제한없음',
#  '11~2월 : 09:00~17:30 (12월 17:00)<br />\n3~4월, 9~10월 : 09:00~18:00 <br />\n5~8월 : 09:00~18:30 (7월말~8월중순 19:00)<br />\n※ 자세한 이용시간은 전화문의',
#  '캠핑, 카라반 12:00 ~ 익일 12:00<br>펜션 15:00 ~ 익일 11:00',
#  '입실 14:00~20:00, 퇴실 12:00<br />\n샤워장 운영시간 08:00~22:00',
#  '입실 14:00<br>퇴실 익일11:00',
#  '일출, 일몰 시간을 감안하여 탄력적으로 운영<br />※ 자세한 이용시간은 홈페이지 참조',
#  '평일 07:00 ~ 20:30 / 주말 10:00 ~ 17:30',
#  '15:00~익일10:30',
#  '15:00~익일 11:00<br>※ 조기 입실, 지연 퇴실 불가능',
#  '[평일] 06:00~22:00<br>[주말, 공휴일] 06:00~20:00<br>※ 17:00~18:00 방역 및 환기 시간으로 운동 불가',
#  '매일 09:00~22:00',
#  '상시이용 가능, 방문 전 통제구간 확인 요망',
#  '입실 12:00 ~ 퇴실 12:00',
#  '상시이용',
#  '09:00~18:00 <br>동절기 10:00~17:00',
#  '상시',
#  '일출~일몰',
#  '10:00~17:00<br> - 1부 10:00~12:00<br> - 2부 12:30~14:30<br> - 3부 15:00~16:50',
#  '하절기 04:30~22:00<br>동절기 05:00~21:00',
#  '[ 평일 ] 13:00~21:00 / [ 주말 ] 10:00~21:00',
#  '[오토캠핑]<br>13:00~익일 12:00<br>[글램핑]<br>14:00~익일 12:00',
#  '10:00 ~ 17:00',
#  '12:00 ~ 익일 14:00',
#  '경기 일정에 따라 상이',
#  '00:00 ~ 24:00',
#  '하절기 09:00 ~ 18:00 (입장마감 16시)<br> 동절기 09:00 ~ 17:00 (입장마감 15시)',
#  '09:00~17:00',
#  '전화 문의',
#  '- 입실시간 : 15:00~21:00(늦을 경우 사전에 연락)<br>- 퇴실시간 : 11:00까지',
#  '일요일~목요일 09:00~18:0 <br>금요일~토요일 09:00~21:00',
#  '14:00~20:00',
#  '- 입실: 당일 14:00 부터<br />- 퇴실: 다음날 낮 12:00 까지',
#  '오토캠핑 14:00 ~ 익일 12:00 <br>글램핑 15:00 ~ 익일 11:00',
#  '12:00 ~ 익일15:00',
#  '- 3~10월 : 10:00 ~ 18:00<br/>- 11~2월 : 평일- 10:00 ~ 17:00, 주말- 09:30~ 17:00<br>※평일 브레이크 타임 시행 12:30~13:30<br>※티켓팅/입장 마감 : 운영 종료 시간 30분 전까지',
#  '월~금 14:00~17:45 / 주말 12:00~17:45',
#  '09:00 ~ 20:00',
#  '일출부터 일몰까지<br>※ 자세한 안내는 홈페이지 참조',
#  '매일 09:00 - 19:00 일몰까지',
#  '15:00 ~ 익일11:00',
#  '09:00 ~ 17:00(예약 체험시간 참고)',
#  '08:00~19:30 (입장마감 18:30)',
#  '15:00 ~ 익일 14:00',
#  '요일별 이용시간 상이함으로 자세한 안내는 전화 문의 요망',
#  '주중 05:00~20:00<br>주말 04:30~20:00<br>티켓팅 마감 19:00 <br>※이용시간은 변동될 수 있으므로 홈페이지 참조 또는 전화 문의 요망',
#  '09:00~익일 15:00',
#  '입실 15:00~18:00<br/> 퇴실 11:00',
#  '오토캠핑 14:00 ~ 익일 11:00<br>글램핑 15:00 ~ 익일 11:00',
#  '12:30 ~ 익일 12:00',
#  '08:00~18:00 (점심시간 12:00~14:00)',
#  '수영(강습) - 평일 06:00~21:50<br />헬스장 - 월~토 06:00~21:50',
#  '06:00 ~ 23:00 (토요일 06:00 ~ 19:00 / 공휴일 10:00 ~ 17:00)',
#  '13:00~익일1 2:00',
#  '00:00~23:00',
#  '13:00 ~ 익일12:00',
#  '[평일]<br>- 06:00~21:00<br>[토요일∙공휴일]<br>- 06:00~18:00',
#  '14:00~익일11:00<br>매너타임 22:00~07:00',
#  '월요일~금요일 10:00~24:00<br>토요일~일요일 10:00~02:00<br>서핑스쿨 운영시간 10:00~18:00',
#  '날씨에 따라 상이 <br>※ 전화문의',
#  '[운영 시간]<br> 평 일 : 06:00 ~ 21:00<br> 토요일 : 06:00 ~ 18:00<br> 일요일 : 둘째·넷째주 운영 09:00~18:00<br> [자유 수영] 1일 1회 2시간이내 이용<br> 토요일 06:00~11:50 / 13:00~17:50<br> 일요일 및 공휴일 09:00~11:50 / 13:00~17:50',
#  '14:00~익일 11:30',
#  '09:00~18:00 (성수기 09:00 ~ 19:00)',
#  '상시이용 가능',
#  '유인인증 09:00~17:00',
#  '월요일 09:00 ~ 17:00<br />화,금요일 09:00 ~ 18:00<br />토,일요일 09:00 ~ 17:00<br />평일정빙시간 11:50~13:00, 15:45~16:00, 17:45~18:00<br />주말정빙시간 11:50~13:00, 14:45~15:00, 16:45~17:00',
#  '10:00~익일 10:00<br>* 당일 입실시간 관계없이 다음 날 10:00 퇴실 기준',
#  '09:00 ~ 일몰시간',
#  '캠핑 14:00~익일12:00<br>글램핑 15:00~익일11:00',
#  '입실일 14:00~ 퇴실일 다음날 11:00',
#  '매주 금/토/일 11:00~19:00<br>※ 자세한 사항은 홈페이지 참조',
#  '06:30 - 19:00',
#  '캠핑장 14:00~익일11:00<br>카라반/방갈로 15:00~익일11:00',
#  '동절기 09:00~18:00<br>하절기 09:00~19:00<br>※ 기상상황에 따라 변동될 수 있음<br />※ 매월 첫째, 셋째 주 화요일 정기 점검일',
#  '예약 시간별 상이',
#  '회원 예약제 운영',
#  '12:00~익일 12:00',
#  '매달 변동가능하므로 홈페이지 참조 요망',
#  '- 9월, 10월 : 08:00~15:00<br>- 11월 : 08:00~14:00<br>※ 상세한 이용시간 홈페이지 참조',
#  '[주간] 09:00~18:00 / [야간] 18:00~06:00',
#  '*오토캠핑 <br>입실 - 14:00<br />퇴실 - 익일 11:00 <br />*글램핑  <br>입실 - 15:00 (입장은 당일 20:00 이전까지 완료)<br />퇴실 - 익일 11:00 <br>※ 퇴실시간 초과시 추가요금 징수<br />* 매점운영 : 09:00~ 21:00',
#  '09:00~21:00 <br>점심시간 12:00~13:30',
#  '15:00~익일12:00',
#  '오토캠핑 13:00 ~ 익일 12:00 <br>글램핑, 펜션, 카라반 14:00 ~ 익일 11:00',
#  '12:00~19:00',
#  '평일 12:00 ~ 익일12:00<br>토요일 08:30 ~ 익일12:00(연휴가 있는 주는 12시30분 입실)',
#  '09:00 ~ 19:00',
#  '15:00~익일11:00<br>※ 당일 이용가능도 가능하므로 홈페이지 참조 요망',
#  '- 평일 : 18:00~22:00 <br>- 토요일 : 13:00~18:00  <br>- 일요일 / 공휴일 : 10:00~18:00 <br>※ 낮에는 선수들이 이용',
#  '09:00 ~ 17:00',
#  '09:00 ~ 17:30',
#  '[비수기(3월~7월 / 9월~12월)]<br>- 주중 13:00~17:00<br>- 주말 10:00~17:00<br>[성수기(1~2월 / 8월)]<br>- 주중 10:00~17:00<br>- 주말 10:00~18:00',
#  '매일 06:00 ~ 23:59',
#  '당일입장~익일09:00',
#  '09:30~17:00 (휴게시간 12:00~13:00)<br> 하절기 입장마감 17:00<br> 동절기 입장마감 16:30',
#  '[카라반]<br>- 15:00 ~ 익일 11:00<br>[한옥]<br>- 16:00 ~ 익일 12:00',
#  '하절기 개방시간 (4월~9월) <bs>06:00~20:00<bs>동절기 개방시간 (10월~3월)<bs>07:00~18:00',
#  '18:00~21:00',
#  '이용시간 제한은 없으나 가급적 야간에는 이용을 금하기 바람',
#  '오토캠핑, V데크 사이트 09:00 ~ 익일 12:00 <br>글램핑, 펜션 15:00~익일 12:00',
#  '24시간 운영',
#  '숙박시설 13:00 ~ 익일 10:00<br>부대시설 대관 09:00 ~ 22:00',
#  '춘하추절기 :00:00~24:00/동절기 : 09:00~18:00',
#  '월~금 : 06:00~22:00 / 토 : 07:00~ 17:40',
#  '하절기 08:00~18:00<br>동절기 09:00~18:00',
#  '오토캠핑 14:00~익일 12:00<br>카라반 15:00~익일 11:00<br>※ 매너타임 22:00~07:00',
#  '[평일]<br>  - 09:00~22:00  <br>* 09:00~19:00 선수 이용  <br>* 19:00~22:00 일반인 이용 <br>[주말]<br>  - 09:00~18:00 일반인 이용<br>※ 점심시간 12:00~13:00',
#  '서프존 10:00~18:00<br>미오코스타존 10:00~17:00<br> ※ 자세한 사항은 홈페이지 참조',
#  '봄·여름 : 10:00~18:00 <br>가을·겨울 : 10:00~16:00',
#  '09:00~22:00<br>(운항 시간 11:00 / 12:00 / 13:00 / 14:00 / 15:00 / 17:00 / 18:00 / 19:00 / 20:00 / 21:00 / 22:00)',
#  '12:00~익일11:00',
#  '글램핑 15:00~익일11:00<br/>캠핑장 14:00~익일13:00',
#  '- 비수기 14:00~익일 12:00<br>- 성수기 15:00~11:00',
#  '이용 프로그램에 따라 상이하므로 홈페이지 참조 및 전화문의 요망',
#  '[빙상장 운영시간] 07:00~23:00<br> [일반인 이용시간]<br> - 평일, 주말 : 13:00~18:00<br> - 목요일 : 13:00~18:00(주간) / 20:00~22:00(야간)',
#  '09:00~익일 21:00',
#  '- 캠핑장 14:00~익일13:00<br>- 펜션 14:00~익일12:00',
#  '12:30~익일12:00<br>시설별 정확한 이용시간은 홈페이지 참조',
#  '16:30 ~ 익일 11:00',
#  '14:00~익일 12:00<br />성수기(7월 15일 ~ 8월 20일)에는 사용시간 연장이 불가',
#  '평일, 일요일 07:30 ~ 23:00  *노지 낚시는 24시간<br>토 - 24시간',
#  '입장시간 : 09:00~18:00 / 숙박시설 : 14:00 ~ 익일11:00',
#  '14:00~익일 11:50',
#  '상시운영',
#  '[하절기]<br>- 10:00~18:00<br>[동절기]<br>- 09:30~17:00',
#  '*하절기(3월 - 10월) 08:00-19:00<br />\n*동절기(11월 - 2월) 08:00-17:00',
#  '[여름물썰매장] 10:00 ~ 17:00<br>[겨울눈썰매장] 10:00 ~ 17:00',
#  '[4~10월] 10:00~19:00<br>[11~3월] 10:00~17:00',
#  '좌대 : 12:00~익일 10:00<br>배 : 07:00~19:00',
#  '입실 12:00 / 퇴실 10:00',
#  '07:00~24:00',
#  '09:00~18:00 <br>※ 휴게시간 : 12:00~13:30',
#  '캠핑 14:00 ~ 익일 12:00<br>글램핑 14:00 ~ 익일 11:00',
#  '06:00~20:00 (기상상황에 따라 변동 가능. 자세한 사항은 전화 문의 요망)',
#  '13:00~익일13:00',
#  '11:00~20:00',
#  '일출 20분 전 티업~일몰 3시간 전 티업',
#  '12:00 ~ 익일13:00',
#  '09:00~익일 16:00',
#  '[캠핑장]<br>- 12:00 ~ 익일 11:00<br>[숙박]<br>- 14:00 ~ 익일 11:00',
#  '계절 및 날씨에 따라 변동되므로 전화문의',
#  '첫 Tee Off : 일출 20분 전 <br>\n마지막 Tee Off 일몰 5시간 이내',
#  '회원제로 운영',
#  '하절기(3~10월) : 09:00~18:00<br>동절기(11~2월) : 09:00~17:00',
#  '비수기 09:30-17:30<br>성수기 09:30-18:30',
#  '평일 06:00 ~ 22:00 <br>\n공휴일 06:00 ~ 20:00 <br>\n일요일 08:00 ~ 20:00',
#  '일반개장 : 10:00 ~ 16:50<br />\n선수훈련 시간 : 06:00 ~ 10:00 / 17:00 ~ 24:00<br />\n휴강일 : 별도공지',
#  '이른 오전~18:00',
#  '06:00~22:00<br>※시설별 상이',
#  '금요일 : 11:00~11:05 <br>※전화문의 요망',
#  '[동절기(12월~2월)]<br>- 주중 07:00~22:00<br>- 주말·공휴일 07:00~21:00<br>[하절기] <br>- 주중 06:00~23:00<br>- 주말·공휴일 06:00~22:00',
#  '일출 ~ 일몰',
#  '13:00~익일10:00',
#  '11:00 ~ 익일 14:00',
#  '- 오토캠핑 13:00~익일 12:00<br>- 글램핑 15:00~익일 11:00',
#  '입실 14:00 / 퇴실 익일 12:00',
#  '10:00~18:00 (발권 마감 17:45)',
#  '※ 전화문의 요망',
#  '동절기(11~3월) 05:00~13:00, 하절기(4~10월)  04:00~14:00',
#  '11:00~17:00 (경기장 사정에 따라 변동)<br />\n※ 자세한 사항은 해당 홈페이지 확인 ☞ <a href="https://blog.naver.com/j6410420"target="_blank" title="새창: 운영시간 안내 ">https://blog.naver.com/j6410420</a>',
#  '- 캠핑 13:00~익일11:00<br>- 카라반 14:00~익일11:00',
#  '주중 11:00~19:00<br>주말 10:00~20:00',
#  '[캠핑] 14:00~익일 11:00<br>[펜션] 15:00~익일11:00',
#  '- 하절기 09:00~18:00<br>- 동절기 09:00~17:00',
#  '놀이기구패키지 / 계곡물놀이 / 카약 09:00~18:00 <br>수상스키 / 웨이크보드 / 초보자강습 07:00~20:00',
#  '입실 - 15:00<br>퇴실 - 11:00',
#  '일출부터 일몰까지 /  야간 (17:00~21:00)',
#  '08:00~22:00(체육시설 09:00~18:00)',
#  '[캠핑장] 13:00~익일 12:00 <br>[평상] 10:00~19:00',
#  '15:00 ~ 익일 11:00',
#  '14:00 ~ 익일 13:30',
#  '공연별 상이',
#  '~ 익일12:00',
#  '09:00~일몰(변동 가능)',
#  '[자동차 야영지]<br>- 14:00~익일 12:00<br>[하우스]<br>- 15:00~익일 11:00',
#  '09:00 ~ 17:00<br>09:00 ~ 21:00 (하절기)<br>※ 점심시간 12:00 ~ 15:00',
#  '09:00~18:30<br>※일몰 시간에 따라 변경될 수 있음',
#  '09:00 - 18:00',
#  '[하절기(4월~10월)]<br />- 주간 평일,토요일,일요일 09:00~18:00<br />- 야간 평일 18:00~22:00<br />[동절기(11월~3월)]<br />- 주간 평일,토요일,일요일 09:00~17:00<br />- 야간 평일 17:00~21:00',
#  '13:00~22:00',
#  '입실 14:00 / 퇴실 12:00',
#  '[승마 투어]<br>- 3~10월 09:00~19:00<br>- 11~2월 09:00~17:30<br>[목장 투어]<br>- 화/수/목 14:00, 17:00<br>※ 일몰 시간에 따라 영업마감시간이 변동될 수 있음',
#  '연중무휴',
#  '첫 Tee-Off(일출이후)~마지막 Tee Off(일몰 5시간 이전)',
#  '예약상황에 따라 유동적으로 운영 (전화문의)',
#  '예약 시 문의 요망',
#  '14:00~익일 10:30',
#  '봄·여름 : 10:00~18:00<br>가을·겨울 : 10:00~16:00',
#  '09:00~17:00 (12:00~14:00 점심시간)',
#  '09:00~19:00(12:00~13:00 휴게시간)',
#  '수시 변동(홈페이지 확인)',
#  '상시 (전화문의)',
#  '08:00~20:00 (12:00~14:00 휴게시간)',
#  '[ 평일 ] 11:00~22:00 / [ 토요일 ] 08:00~17:00',
#  '06:00 ~ 23:30',
#  '텐트 14:00~익일11:00<br>카라반 15:00~익일11:00',
#  '예약에 따라 탄력적',
#  '[회차 출발 시간] 오전 10:00 / 오후 14:00',
#  '예약제 운영',
#  '시기별 이용시간 상이하므로 홈페이지 참조 또는 전화 문의 요망',
#  '입실 12:00 / 퇴실 익일 12:00',
#  '[ 월요일 ] 09:00~19:00 / [ 화요일~일요일 ] 09:00~22:00',
#  '[패밀리 풀, 인피니티 풀]<br>- 5~6월, 9월 : 12:00~20:00<br>- 7~8월 : 10:00~23:00',
#  '월요일~목요일 14:00 ~ 21:30<br>금요일~일요일 14:00~22:30',
#  '10:00~익일 09:00<br>※ 자세한 이용시간은 전화 문의 요망',
#  '09:00~19:00',
#  '야구 경기가 열리는 시간~종료시간',
#  '상시개방',
#  '입실 15:00<br/>퇴실 11:00',
#  '프로그램 운영시간 별도 안내 (인스타그램 메시지 / 네이버스마트스토어)',
#  '09:30~17:30',
#  '15:00 ~익일 11:00',
#  '일요일 ~ 목요일 09:00 ~ 17:00 (매표마감 16:00)<br>금요일 ~ 토요일, 하계 성수기 09:00 ~ 19:00 (매표마감 18:00)',
#  '일출과 일몰시간에 따라 변동',
#  '경기 일정에 따라 상이함 <br>※ 야구 개장 2시간 전',
#  '22:00 전 자유입장 ~ 익일 15:00',
#  '[입산가능 시간]<br>- 11월~3월: 05시~14시<br>- 4월~10월: 04시~15시',
#  '예약제로 운영',
#  '실내 수영장 06:00~21:00<br />실외 수영장 11:00~20:00<br />사우나 06:00~21:00<br />헬스 06:00~21:00<br />※ 실외수영장은 여름시즌에만 운영',
#  '[화요일~금요일] 06:00~22:00(입장마감 21:00) <br>[주말] 08:00~16:00(입장마감 15:00) <br>※ 휴게시간 14:00~15:00',
#  '[A~B구역(자동차야영지)]<br>- 14:00~익일 12:00<br>[C구역(카라반),D구역(특화야영장 하우스형)]<br>- 15:00~익일 11:00',
#  '상시개장',
#  '09:00 ~ 22:00',
#  '입실 12:00 ~ 퇴실 11:00',
#  '퇴실 12:00',
#  '[숙박시설]<br>- 성수기, 주말, 공휴일 15:00~익일11:00<br>- 평일 14:00~익일11:00<br>[캠핑]<br>- 전 기간 15:00~익일12:00',
#  '수영장 : 09:00~17:00 캠핑 : 13:00~익일 12:00',
#  '체크인 14:00 ~ 체크아웃 익일11:00',
#  '10:00~18:30',
#  '입실 12:30 ~ 퇴실 12:00',
#  '캠핑 13:00 ~ 익일 12:00<br>피크닉 13:00 ~ 21:00',
#  '[글램핑] 입실 15:00 / 퇴실 11:00<br>[캠핑] 입실 13:00 / 퇴실 12:00',
#  '캠핑장 13:00 ~ 익일 11:00 <br>펜션, 카라반, 글램핑 15:00 ~ 익일 11:00',
#  '14:00 - 익일 12:00',
#  '예약시문의',
#  '09:00~18:00 (16:00까지 입장 마감)',
#  '11:00 ~ 익일12:00',
#  '입실 14:00~18:00<br>퇴실 익일12:00<br>※ 매너타임 22:00~07:00',
#  '06:00 ~ 23:00',
#  '06:00~21:00<br>※ 새벽반, 야간반은 회원수급이나 승마장 운영인력 수급 등에 따라 탄력적 운영',
#  '10:00~17:00 (여름성수기 10:00~18:00)',
#  '10:00 ~ 16:00',
#  '16:00~익일11:00',
#  '06:00~22:00 / 시설별 상이함',
#  '하절기(3월~10월) : 09:00~18:00<br>동절기(11월~2월) : 09:00~17:00<br>※ 마감 1시간 전부터 입장 통제, 현장 기상여건에 따라 운영시간 변동',
#  '13:00 입영 / 익일 12:00 퇴영',
#  '일출시간 30분 후 ~ 일몰시간 5시간 이내',
#  '예약된 시간 이용가능',
#  '- 캠핑 14:00~익일12:00<br>- 펜션 15:00~익일11:00',
#  '09:30~19:30',
#  '화~일 08:00~18:00 (점심시간 12:00~14:00)',
#  '평일 09:00~22:00 / 토요일 09:00~20:00 / 일요일 09:00~18:00',
#  '[곤돌라 이용시간] <br>- 주중(일~목) : 10:00~18:00 <br>- 주말(금~토) : 10:00~20:00',
#  '월,수,금 - 10:00~22:00<br>화~목 - 13:00~22:00<br>주말 - 10:00~20:00',
#  '10:00 ~ 12:00, 13:00 ~ 15:00, 15:30 ~ 17:00',
#  '09:00~17:00<br>(입장마감 16:30)',
#  '- 캠핑 12:00~익일11:00<br>- 글램핑/카라반/캠핑체험 15:00~익일11:00',
#  '24시간 개방 (자율입산제)<br>[계절별 탐방 권장 시간]<br>- 겨울 (11~2월) 09:00~17:00(15:00까지 입산)<br>- 봄,가을(3~4월/9~10월) 07:00~18:00(16:00까지 입산)<br>- 여름(5~8월) 07:00~19:00(17:00까지 입산)',
#  '[방학전]<br> -월~목 15:00~17:50<br> -금 15:00~16:50<br>[방학기간]<br> -월~목 12:00~17:50<br> -금 12:00~16:50<br> -토 12:00~14:50<br> -일 10:00~14:50',
#  '[수련관]<br> 09:00 ~ 20:00<br> [방과후아카데미]<br> 17:00 ~ 20:00',
#  '[실내존]<br>- 준성수기: 10:00~16:30<br>- 하계 성수기: 09:00~19:30<br>[실외존]<br>- 준성수기: 11:00~16:30<br>- 하계 성수기: 09:00~19:00<br>※ 준성수기 (5.1~7.11 / 8.26~10.13), 하계 성수기 (7.12 ~ 8.25)<br>※영업 상황에 따라 시간이 변경될 수 있으므로 방문일에 꼭 다시 한 번 확인 요망',
#  '평일 10:00~22:30 / 주말 / 공휴일 11:00~20:00',
#  '비수기 10:00~18:00 (마지막탑승 17:30)<br />성수기(5~9월) 10:00~19:00 (마지막탑승 18:30)',
#  '주말 및 공휴일 1일 2타임제 운영 - A타임(오전) : 10:30~15:30 / 5시간  - B타임(오후) : 17:00~22:00 / 5시간 ※ 평일 : 원하는 시간대 이용 문의',
#  '월요일~금요일 07:00~22:45<br>토요일 07:00~23:30<br>일요일 07:00~21:45',
#  '14:00~익일13:50',
#  '14:00 ~ 익일11:00',
#  '하절기(4~9월 ): 06:00~20:00 <br>동절기(10~3월) : 06:00~18:00<br>평일 : 16:00~18:30 (대구시 대표선수단 훈련시간)<br>야간 : 19:00~20:00<Br>조기 : 06:00~09:00 (사전예약)',
#  '캠핑 13:00~익일12:00<br>글램핑 15:00~익일11:00',
#  '13:00 ~ 익일11:00',
#  '13:00 ~익일 11:00',
#  '하절기 09:00~19:00(해질녂까지)<br />동절기 09:00~17:00(해질녂까지)<br />※ 카트체험 만 이용할 경우 마감 30분까지<br />※두 개 이상의 체험 이용 시 마감 1시간 전까지',
#  '10:30 ~ 22:00',
#  '10:30~17:00',
#  '캠핑: 14:00 ~ 익일12:00',
#  '13:00 ~ 익일 10:00',
#  '평일 13:00~22:00 / 토요일 11:00~23:00 / 일요일 11:00~21:00',
#  '당일 14:00 ~ 익일 11:00',
#  '경륜경기 일정 : 금, 토, 일',
#  '첫 Tee-Off 일출 30분 후/ 마지막 Tee-Off 일출몰 5시간 이내',
#  '입실 15:00 <br>퇴실 익일11:00',
#  '07:00 ~ 21:00',
#  '10월~3월 09:00~18:00 / 4월~9월 09:00~20:00 <br>토·공휴일 09:00~18:00',
#  '제한 없음',
#  '8:00~18:00',
#  '홈페이지주소 참조',
#  '야영장 12:00~익일 11:00<br>전객실 14:00~익일11:00',
#  '10:00 ~ 18:00<br />\n※ 주중 이용시 사전 유선 예약필수',
#  '캠핑 14:00 ~ 익일12:00<br>글램핑 14:00 ~ 익일11:00',
#  '주중 06:00~22:00 <br>토요일 09:00~17:00',
#  '09:00 ~ 18:00<br />\n※ 전화문의 요망',
#  '수련활동 내용에 따라 상이',
#  '캠핑 15:00 ~ 익일13:00',
#  '월요일 ~ 금요일 10:30 ~ 23:00<br>토요일 12:00 ~ 19:00',
#  '14:00 ~ 익일 10:00',
#  '- 월~금 : 14:00~22:00<br>- 토~일 / 방학기간 : 10:00~22:00',
#  '주말(금~일) 및 공휴일 12:00~21:00',
#  '상시 개방',
#  '일출~일몰, 야간',
#  '[3~10월]<br>- 09:00~17:30<br>- 휴게시간 12:10~13:00<br>[11~2월]<br>- 9:00~16:30<br>- 휴게시간 12:10~13:00<br><br>※ 설날, 추석당일에는 13:30 부터 영업시작<br>※ 탑승시간은 홈페이지 참고',
#  '[일반인] 10:00~12:00 / 13:00~18:00 <br>[대관] 06:00~09:00 / 18:00~22:00',
#  '[연습장]<br>- 07:00 ~ 22:00 <br>[part3]<br>- 08:00 ~ 17:00',
#  '평일 10:00~18:00<br />주말,공휴일 10:00~18:00(탄력적 연장 운행)<br />※ 마지막 출발 17:30',
#  '13:00 ~ 익일 12:00',
#  '계절에 따라 유동적(전화로 예약)',
#  '09:00 ~ 18:00 (휴게시간 12:00 ~ 14:00)',
#  '하절기 09:00~19:00 / 동절기 10:00~17:00',
#  '월~목 11:00~20:00<br>금 11:00~21:00<br>토 10:00~21:00<br>일 10:00~20:00',
#  '대관시간 06:00~24:00',
#  '비수기 14:00, 성수기 15:00 ~ 11:00 (익일)',
#  '※ 자세한 사항은 홈페이지 참고',
#  '일출시간부터 일몰시간까지',
#  '13:00  ~ 익일 12:00',
#  '하절기 06:30~21:00 / 동절기 08:00~17:30 / 춘추 07:00~18:00',
#  '08:00~20:00',
#  '입실 14:00 ~ 퇴실 11:00',
#  '입실 15:00<br>퇴실 1:00',
#  '[카라반존/캐빈 하우스]<br/>입실시간 14:00<br/>퇴실시간 11:00',
#  '시즌별 이용시간 상이함으로 홈페이지 참조',
#  '06:00~22:00',
#  '09:00~17:00 (17:00 까지 퇴장) / 우천 및 폭설 시 통행 제한 있을 수 있으므로 방문 전 유선 확인 필요',
#  '07:00~23:30',
#  '11:30~익일 11:00<br>※ 당일 입실시간 관계없이 다음 날 11:00 퇴실 기준',
#  '일출~일몰 (전화문의)',
#  '연중개방<br>※ 방문 전 통제구간 확인 요망',
#  '09:00 ~ 17:00 <br>※ 예약에 따라 상이',
#  '입실 13:00~22:00 / 퇴실 12:00까지',
#  '일출 후~일몰 전',
#  '10:00~익일 09:30',
#  '매주 화요일 휴무<br>10:00~17:00(슬로프 마감은 마감시간 30분전) <br>※ 우천 시 휴장<br>※ 동절기 운영',
#  '오후 2시, 5시, 6시30분 (경기 일,월에 따라 시작시간 상이)',
#  '금, 토, 일요일 체크인 13:00 / 체크아웃 익일 12:00<br>※ 전팀이 없을 경우 오전 9시부터 입촌 가능',
#  '07:00~익일12:00',
#  '＊주중ㆍ주말<br />\u3000입실 14:00 / 퇴실 11:00<br />＊성수기<br />\u3000입실 14:00 / 퇴실 11:00<br /><br />＊입실 전, 퇴실 후 스파 무료이용 불가',
#  '오토캠핑 12:00~익일11:00',
#  '12:00~익일11:30',
#  '[평일] 동절기 09:00~21:00 / 하절기 08:00~21:00  <br>[주말 및 공휴일] 09:00~18:00',
#  '주중 06:00 ~ 23:00<br>주말 06:00 ~ 22:00',
#  '08:00~익일 12:00',
#  '주중 11:00 ~ 21:00 <br>주말,공휴일,방학 10:00 ~ 21:00',
#  '15:00 ~ 익일 13:00',
#  '하절기(3월~10월) 09:00~18:00<br> 하절기(11월~2월) 09:00~17:00 <br>(12:00~13:00 휴게시간)',
#  '프로그램 별 이용 시간 상이함으로 홈페이지 참조 요망',
#  '15:00 ∼ 익일 12:00',
#  '10:00 ~ 익일 14:00 <br>※ 연휴기간 13:00 ~ 익일 12:00',
#  '09:00~17:30',
#  '하절기 09:00~18:00 <br />\n동절기 09:00~17:00 <br />\n※ 수요일 09:00~12:00 시설점검',
#  '첫 팀 Tee-Off 1시간 전 ~ 21:00',
#  '11:00 ~ 익일13:00',
#  '09:30~17:00(휴게시간 12:00~13:30)',
#  '평일 13:00~22:00 (입장마감 21:30)<br>주말 및 공휴일 10:00~22:00 (입장마감 21:30)<br>※ 주중 3시간, 주말 및 공휴일 2시간 이용가능',
#  '동절기 운영 10:00~18:00<br>※ 자세한 이용시간은 홈페이지  참조 및 전화 문의 요망',
#  '7:00 ~ 18:00 (계절별 변동 있음)',
#  '00:00 ~ 24:00<br>1인/2인/3인 방가로 11:00 ~ 10:00(익일)',
#  '13:00~익일12:00<br>※ 정확한 이용시간은 홈페이지 참조 및 전화문의 요망',
#  '입실 15:00 ∼ 퇴실 14:00',
#  '평일 08:00~23:00 / 주말 및 공휴일 10:00~20:00',
#  '화~금요일 : 13:00~22:00<br>토~일요일, 공휴일 : 10:00~21:00',
#  '10:00~22:00 (12:00~13:00 휴게시간)',
#  '10:00~익일 14:00',
#  '09:40 ~ 17:50 (휴게시간 12:00 ~ 13:30)',
#  '08:00~18:00',
#  '07:00 ~ 22:00',
#  '09:00~18:00(점심시간 12:00~12:40)',
#  '오토캠핑장 13:00~익일 12:30<br>글램핑 14:00~익일 11:00',
#  '평일 11:00~23:00<br>토요일 10:00~24:00<br>일요일 10:00~21:00',
#  '09:00~18:00 <br />* 7~8월 성수기 21:00까지 야간번지 실시 (전화문의)',
#  '[피크닉존]<br>- 1회차 : 12:00~16:00<br>- 2회차 : 17:00~21:00<br><br>[카라반] : 12:00~21:00<br><br>[키즈존]<br>- 주중(수목금 종일권) : 15:00~18:00<br>- 주말(토일 종일권) : 12:00~18:00<br>- 주중(수목금 쿼터권) : 16:00~18:00<br>- 주말(토일 쿼터권) : 16:00~18:00<br><br>[레스트존] : 13:00~21:00',
#  '10:00 ~ 18:00 (점심시간 12:00~13:00)',
#  '13:00~17:00',
#  '1회차 09:00 / 2회차 10:30 / 3회차 13:00 / 4회차 14:30 / 5회차 16:00<br />\n※ 셔틀버스 운행소요시간 20분~30분 / 레일바이크 운행소요시간 1시간 소요',
#  '[일반]<br>- 주간 08:00 ~ 17:00<br>- 야간 19:00 ~ 07:00<br>[숙박]<br>- 14:00~익일11:00',
#  '2월 ~ 10월 09:00 ~ 18:00<br />\n11월 ~ 1월 09:00 ~ 17:00',
#  '[하절기] 09:00~18:00<br>[동절기] 09:00~17:00<br>※ 점심시간 12:00~13:30',
#  '입실 14:00~ 퇴실 익일12:00',
#  '- 입장 13:00~21:00<br>- 퇴장 12:00',
#  '11:00 ~ 20:00',
#  '*자유 수영 <br />-평일 13:30 ~ 15:30<br />- 토·일·공휴일 09:00 ~ 17:00<br />* 종목별 강습 프로그램 시간은 홈페이지 참조 요망 ()',
#  '입실 15:00/퇴실 11:00',
#  '09:00~16:00 (점심시간 12:00~13:00)',
#  '선박별 상이 홈페이지 참조',
#  '캠핑 14:00~익일 13:00',
#  '[해상펜션] 15:00~익일 10:00<br>[선상낚시체험] 08:00~12:00 / 13:00~17:00',
#  '12:00 ~ 익일 11:00',
#  '주중 10:00~23:00<br>주말 및 공휴일 10:00~20:00',
#  '3월~11월 05:00~23:00<br>12월~2월 05:00~23:00',
#  '10:30~21:00',
#  '하절기(3월~10월) 09:00 ~ 16:00<br>동절기(11월~2월) 09:00 ~ 15:00',
#  '입실 15:00 ~ 퇴실 11:00',
#  '라운딩 18홀 기준 4시간 30분~5시간',
#  '09:00~18:00(17:30 매표마감) <br>성수기(7월 중순~8월 중순) 09:00~19:00(18:30 매표마감)',
#  '주중 10:00 ~ 24:00 <br>주말 08:00 ~ 24:00',
#  '08:00~18:00<br>(성수기 기준, 계절 및 기상 상황에 따라 변동가능)',
#  '09:00~18:00<br>*여름철에만 개장',
#  '[캠핑]<br/>14:00~익일 13:00<br/>[펜션]<br/>14:00~익일 11:00',
#  '13:00 ~ 다음날 12:00',
#  '15:30~익일 11:00',
#  '- 평일 08:00~21:00<br>- 토요일, 공휴일 전날 00:00~24:00',
#  '3월~11월 : 9:00~19:30<br>12월~2월 : 9:00~18:30',
#  '08:00~20:00(휴게시간 12:00~13:00)',
#  '글램핑 15:00 ~ 익일 11:00<br>캠핑 12:00~익일12:00',
#  '※ 홈페이지 참조',
#  '- 걷기 시작시간 09:00<br />- 걷기 종료시간 18:00(하절기) / 17:00(동절기)',
#  '09:00~12:00 / 13:00~18:00',
#  '주중 13:00~22:00<br>주말 10:00~13:00',
#  '15:00~익일 14:00',
#  '화~금요일 09:00~21:00<br>토~일요일 09:00~18:00',
#  '- 12~2월 : 10:00~17:00<br> - 3~10월 : 09:00~18:00',
#  '스노우파크 10:30~17:00 / 경주월드 10:00~18:00',
#  '06:00~익일 11:00',
#  '- 4월~9월 05:00~23:00<br>- 10월~3월 6:00~23:00',
#  '09:00 ~ 익일 22:00',
#  '24시간 (~익일 오전10시까지 이용)',
#  '일~목요일 09:00~18:00<br>금~토요일 09:00~20:00',
#  '시설별 이용시간 상이하므로 홈페이지 참조 요망',
#  '15:00 ~ 12:00(익일)<br />* 성수기 : 5.1 ~11.30<br />\n* 비수기 : 성수기를 제외한 기간',
#  '[화~금요일] 06:00~21:30 (휴게시간 12:00~13:00 / 17:10~18:10)<br>[토~일요일] 06:00~18:30 (휴게시간 11:30~13:00)',
#  '캠핑장 14:00~익일 13:00<br>펜션 15:00~익일 11:00',
#  '평일 : 06:00~22:00 <br> 토·일·공휴일 : 06:00~18:00',
#  '화~일 10:00~18:00',
#  '주간 11:00~16:00 / 야간 17:00~22:00',
#  '14:10 ~ 익일 13:00',
#  '날씨 및 시즌별마다 상이함으로 홈페이지 참조',
#  '캠핑 14:00 ~ 익일12:00 <br>\n글램핑 15:00 ~ 익일 11:00',
#  '10:00~18:00(11월~2월 : 10:00~16:00)',
#  '[캠핑장]<br>입영 - 13:00~22:00<br>퇴영 - 익일 11:00까지<br>정숙시간 - 22:00~07:00<br>[샤워장]<br>09:00~10:00<br>16:00~17:00<br>20:00~21:00<br>※ 총 3회 이용가능하며, 탄력적으로 운영됨',
#  '약 2시간(6.2Km )',
#  '하절기(3~10월) 09:00~18:00, 동절기(11~2월) 09:00~17:00',
#  '오전 체험 낚시 07:00 ~ 12:00 (5시간)<br>오후 체험 낚시 13:00 ~ 17:00 (4시간)',
#  '체크인 14:00<br>체크아웃 12:00',
#  '14:30~익일11:00',
#  '[평일] 14:00~17:00<br>[주말 및 공휴일] 10:00~18:00<br> ※포항아이스링크 사정상 변동될 수 있습니다.',
#  '캠핑 12:00 ~ 익일 12:00<br>객실 14:00 ~ 익일 11:00',
#  '캠핑 13:00~익일 11:00<br>캠프닉 10:00 ~ 17:30',
#  '13:00 ~ 익일 13:00',
#  '08:00 ~ 18:00',
#  '[일일 자유수영]  1부 06:00~11:50 / 2부 13:00~20:50 / 토요일 06:00~16:50',
#  '[2월~11월] 10:00~17:00 <br>[12월~1월] 10:00~16:30',
#  '여름 10:00~18:00<br>겨울 10:00~17:00',
#  '10:00~18:00<br>※ 시즌별 이용시간 상이하니 홈페이지 참조 요망',
#  '상시 개장',
#  '10:00 ~ 익일 12:00',
#  '09:00~06:00',
#  '09:00 ~ 17:00 (전화문의)',
#  '11:00 ~ 익일 12:00',
#  '10:00~17:00',
#  '[일반 텐트존, 쉴터존] 14:00~익일 12:30<br>[타요 카라반] 15:00 ~익일 11:00',
#  '월~금, 일 10:00 ~ 18:00<br /> 토 10:00 ~ 20:00<br />※ 운영시간은 현장 상황에 따라 당일 변동될 수 있음.',
#  '15:00 ~ 13:00(익일)',
#  '주중 06:00~22:00<br>주말 06:00~18:50',
#  '09:00 ~ 20:00(점심시간 12:00 ~ 14:00)',
#  '13:00~익일 13:00',
#  '10:00~17:00 (휴게시간 12:00~13:00)<br />※ 계절에 따라 변경 가능',
#  '일반 야영지 14:00~익일 12:00<br>산막, 하우스 15:00~익일 11:00',
#  '9:30~17:30',
#  '07:00~22:00<br>※ 자세한 이용시간은 전화 문의 요망',
#  '입실 14:00 <br />\n퇴실 12:00',
#  '16:00~익일12:00',
#  '* 산불조심기간 (봄철 2.1~5.15 / 가을철 11.1~12.15) 출입불가<br>* 안전을 위해 일몰 후에는 출입 자제',
#  '08:00~24:00',
#  '09:30~17:00 (점심시간 12:00~13:00)',
#  '11:00~익일 12:00',
#  '금요일 14:00~익일12:00<br> 토요일~일요일 11:00~익일11:00',
#  '06:00~22:30(시기별로 변동)',
#  '08:00~21:00<br>※ 좌대 이용 시 13:00~익일 11:00',
#  '입실 14:00 ~ 퇴실 12:00',
#  '12월~2월 06:30~21:00<br>3월~11월 06:00:22:00',
#  '입실 14:00<br>퇴실 11:30',
#  '14:00 ~ 익일 13:00',
#  '- 화요일 13:00~20:00<br>- 수요일~금요일 11:00~20:00<br>- 주말 11:00~21:00<br>※ 이용 시간은 변동될 수 있으니 방문 전 전화문의',
#  '펜션 14:00 ~ 익일 12:00<br>캠핑 14:00 ~ 익일 13:00',
#  '12:00 ~ 다음날 11:00',
#  '입실 15:00~퇴실 11:00',
#  '일출직후~일몰까지',
#  '야영시설 1일 기준 14:00~익일 11:00',
#  '15:00 ~ 익일 11:00 <br>※전화문의 요망',
#  '15:00~익일14:00',
#  '10:00~익일 14:00<br>※ 7, 8월에는 15:00 퇴실<br>※ 퇴실 당일 예약자가 있을 경우 11:50 퇴실',
#  '14:00~ 익일 12:00',
#  '4월~10월 09:00~19:00',
#  '15:00 ∼ 익일 11:00',
#  '[손오공 / 저팔계 코스] 09:30 / 15:00 / [슈퍼보드 코스] 13:00',
#  '24시간 영업',
#  '09:00~18:00 (점심시간 12:00~13:20)',
#  '변동',
#  '당일 오전 11:30 ~ 익일 오전 11:00',
#  '클레이 사격 09:00~18:00 (이후 사격은 전화 예약) <br>권총/공기총 09:00~18:00 (일몰 후 사격 불가능)',
#  '09:30~18:00 (접수마감 일몰 1시간전)',
#  '12:00 ~ 익일12:00',
#  '오토캠핑 12:00~익일 12:00<br>펜션 14:00~익일 11:00<br>※ 전날 사용객이 없을 경우 조기 입실 가능',
#  '사전 예약 및 전화 확인 필수',
#  '09:00 ~ 18:00<br>※체험별 상이 홈페이지 참조',
#  '00:00 - 24:00',
#  '하절기(3월~10월) : 10:00~22:00<br>동절기(11월~2월) : 10:00~18:00',
#  '월~금 : 10:00~17:45(입장마감 17:00)<br>토 : 11:00~16:45(입장마감 16:00)<br>일 : 대관운영',
#  '[토요일 / 일요일] 09:00~18:00 <br>[화요일~금요일] 09:00~21:00',
#  '[오토캠핑장]<br>- 09:00 ~ 익일 14:00<br>[캐러밴]<br>- 14:00 ~ 익일 11:00',
#  '[월/목/금]<br>하절기 11:00~19:00<br>동절기 11:00~17:30<br>[토/일/연휴 전]<br>하절기 10:00~19:00<br>동절기 11:00~17:30',
#  '캠핑 13:00~익일 12:00<br>펜션, 방갈로 13:00 ~ 익일 11:00',
#  '14:00 ~ 다음날 12:00',
#  '캠핑장 14:00~익일11:00<br>글램핑 15:00~익일11:00',
#  '계절별 상이 <br>※ 홈페이지 참고',
#  '봄·여름 : 10:00~18:00<br> 가을·겨울 : 10:00~16:00',
#  '07:00~20:00',
#  '- 캠핑장 14:00~익일12:00<br>- 펜션 14:00~익일11:00',
#  '11:00~익일12:00',
#  '오전 09:00~12:00 / 오후 14:00~17:00 <br>[야간승마] <br> 여름 18:00~22:00 / 겨울 18:00~19:00',
#  '스카이워크 09:00~18:00',
#  '09:30~17:50',
#  '평일 05:30~11:50 / 13:20~20:20 <br>주말 08:00~11:50 / 13:20~16:50',
#  '하절기:08:00~20:00<br>동절기:10:00~16:00',
#  '15:00~ 익일 11:00',
#  '- 동절기 (11~3월) 05:00~13:00<br>- 하절기 (4~10월)  04:00~14:00',
#  '[학기] 평일 : 13:00~21:00 / 토·일 : 09:00 ~ 18:00 <br>[방학] 평일 : 13:00~21:00 / 토·일 : 09:00 ~ 18:00',
#  '07:00~19:00',
#  '14:00~익일11:00 (4~5월 한시적으로 13시)',
#  '12:00~익일 14:00',
#  '14:00~11:00(익일)',
#  '자유',
#  '매일 07:00 ~ 19:00',
#  '매일 11:00 ~ 22:00',
#  '06:00 ~ 18:00',
#  '이용시간 변동가능하므로 전화문의 요망',
#  '15:00 ~ 익일 15:00',
#  '09:00~19:00<br />※ 전화문의 요망',
#  '24시간',
#  '입실 14:00<br>퇴실 11:00',
#  '6월 주말 12:00~14:00<br>7월 매일 10:00~16:00<br>8월 매일 10:00~16:00<br>9월 주말 12:00~14:00<br>※2시간 간격 운영, 자세한 사항은 홈페이지 참조',
#  '13:00~익일 12:00 (매너타임 23:00 이후)',
#  '주간 09:00~16:30<br>야간 주중 18:00~22:00<br>야간 주말 18:00~23:00',
#  '[회관운영시간] <br />화요일~토요일 09:00~21:00 / 월요일 09:00~18:00<br />[상시이용시설(댄스연습실,방방이,탁구장)]<br /> 09:00~21:00',
#  '일요일~목요일 10:00~21:30<br>금요일, 토요일, 공휴일 10:00~23:00',
#  '15:00 ~ 익일13:00',
#  '평일 10:00~18:00 / 주말 09:00~18:00',
#  '캠핑장:11:00~다음날 10:00<br>피크닉존:10:00~당일 22:00<br>자가텐트:14:00~다음날 13:00',
#  '주간 09:00~18:00 / 야간(7.15~8.15) 18:30~23:00',
#  '15:00~익일13:00',
#  '10:00 - 22:00',
#  '9:30~18:30(마지막 탑승시간 18:00)',
#  '[평일] 06:00~21:00<br> [토요일] 06:00∼18:00 <br>[일요일 및 공휴일] 09:00∼17:00',
#  '화~일 08:00~18:00',
#  '첫 tee-off 일출 30분 후 ~ 마지막 tee-off 일몰 5시간 이내',
#  '월~금 06:00~20:50 / 토 09:00~16:50',
#  '일출~일몰(전화 문의)',
#  '05:00~23:00',
#  '생태체험<br>- 예약 시 문의 <br>야영장 <br>- 14:00 ~ 익일 12:00',
#  '13:00~22:00 (16:00~17:00 휴게시간)',
#  '[글램핑]<br>- 15:00~익일 11:00<br>[캠핑]<br>- 14:00~익일 11:00',
#  '09:00 - 24:00',
#  '14:00~익일12:00<br>※ 성수기 11:00 퇴실',
#  '변동 (홈페이지 참고)',
#  '[월~금]<br>09:30~17:30 <br>평일 휴게시간 11:30~12:50<br>[토,일]<br>09:30~18:00',
#  '00:00~24:00<br>※ 자세한 이용시간은 전화 문의 요망',
#  '[소사벌레포츠타운수영장 / 서평택수영장]<br>06:00~21:00 (12:30~14:00 시설물점검 및 방역)<br> [이충수영장]<br>주중 06:00~21:00<br>주말 06:00~18:00 (12:30~14:00 수질정화시간)',
#  '주중 10:00~17:00<br>주말 10:00~18:00',
#  '[입산제한 시간] 동절기 12:00',
#  '주중 14:00~20:00<br>주말 및 공휴일 10:00~20:00',
#  '09:30~16:30<br>※ 휴게시간 11:30~12:30<br>※ 강설 및 우천 시 운행 중단, 노면이 완전히 건조 된 후 운행 가능',
#  '상시 이용 가능',
#  '10:30~경주종료까지',
#  '캠핑장 14:00 ~ 익일 12:00 <br>숙박 13:00 ~ 익일 12:00',
#  '매일 12:00 - 익일 11:00',
#  '- 캠핑 13:00~익일12:00<br/>- 글램핑 15:00~익일11:00',
#  '화~일 10:00~19:00',
#  '입실 13:00 ~ 퇴실 11:00',
#  '[동절기] 1월 / 2월 / 11월 / 12월 <br>- 06:00 탐방가능 / 15:00 하산 <br>[어리목탐방로] - 12:00 입산제한 <br>[윗세오름안내소(남벽통제)] - 13:00 입산제한 <br>※ 탐방가능여부 홈페이지 참조 <a href="https://www.jeju.go.kr/hallasan/info/info/realtime/course01.htm" target="_blank" title="새창 : 홈페이지로 이동">https://www.jeju.go.kr</a>',
#  '평일 06:00~21:00<br>토요일 09:00~14:00',
#  '[오토캠핑]<br>13:00~익일 11:00<br>[펜션]<br>15:00~익일 11:00',
#  '07:00~21:30',
#  '04:00~17:00<br/>※ 전화문의 요망',
#  '평일 (월요일 ~ 목요일) 06:00 ~ 24:00 <br>\n주말 (금요일 ~ 일요일) 24시간 운영',
#  '금요일~일요일 13:00~익일 11:00',
#  '[연습장] 평일 06:00 ~ 22:00 / 주말 및 공휴일 06:00 ~ 21:00<br>[Par 3] 평일 06:00 ~ 17:00 / 야간 18:30 ~ 선착순 11팀 예약제 / 동절기 07:00 ~ 16:00 (12 ~ 3월)',
#  '11:00~23:00',
#  '8:00~18:00(마지막 레슨 17:00)<br> ※ 계절 및 운영사정에 따라 변경가능',
#  '14:00~익일 14:00',
#  '일출 20분전 ~ 일몰 20분후',
#  '3월~10월 : 10:00~19:00<br>11월~2월 : 10:00~17:00',
#  '하절기:10:00~21:00<br>동절기:10:00~19:00',
#  '월~금 13:00~22:00<br>토,일 11:00~22:00 <br> ※기구정비(긴급)/방송촬영/기상악화 시 운영시간 탄력적 운행',
#  '레일바이크/스위치 백트레인 회차 운영<br/>\n※ 자세한 시간은 홈페이지 참조',
#  '14:00~익일12:00<br>※ 매주 금, 토, 일, 공휴일 전날에만 운영',
#  '입실 15:00 / 퇴실 11:00(매너타임 22:00 이후)',
#  '오후12:00~ 다음날 오전11:00',
#  '09:00 ~ 18:00<br>※ 월 회원은 별도 시간 협의가능',
#  '10:00~18:00 <br>※동절기에는 주말만 운영',
#  '00:00 ~ 24:00 <br>강습 시간 10:00 / 13:00 / 16:00',
#  '야영장 13:00~익일12:00<br>숙박 15:00~익일11:00',
#  '06:00~24:00',
#  '금~일요일 09:30~16:30 (12:00~13:00 미운영)',
#  '11:30~익일 11:00',
#  '하절기 04:00~17:00<br>동절기 04:00~16:00',
#  '14:00 ~ 익일 11:00',
#  '14:00-익일 11:00',
#  '09:30~17:00(휴게시간 12:30~13:30)',
#  '평일 14:00~01:00 / 주말 12:00~04:00',
#  '평일 11:00~23:00<br>주말 및 공휴일 12:00~20:00',
#  '12:00~20:00',
#  '업체마다 상이함',
#  '07:00~22:30',
#  '10:00 ~ 18:00',
#  '06:00~18:00',
#  '12:30~익일 12:00',
#  '13:00~익일 12:00',
#  '14:00~익일 13:00',
#  '09:00~18:00<br>주말 노을카누잉 ~19:00',
#  '08:00~19:00 (일몰까지)',
#  '09:00~익일12:00',
#  '9:00~18:00 <br>※ 수련활동 개별',
#  '* 오전 10시~오후 6시<br />\n* 매시간 : 물놀이 50분, 휴식 10분, 13:30~14:00 물놀이장 청소<br />※ 전화문의 요망',
#  '12:00~익일12:00<br>※ 자세한 이용시간 안내는전화 문의 요망',
#  '10:00~19:00 (12:00~14:00 휴게시간)',
#  '이용별 상이 홈페이지 참조',
#  '[카라반] 15:00~익일 11:00',
#  '10:00 ~ 17:00 (입장마감 16:30)',
#  '14:00~익일12:30',
#  '[일반영지(A,C,D,E)]<br>- 14:00 ~ 익일 12:00<br>[하우스(B,F,G)]<br>- 15:00 ~ 익일 11:00',
#  ...]

# %%
list(set(tourapi['opening_period']))
# Out:
# ['11월 말~3월 초',
#  '하절기 (6월 ~ 8월)',
#  '매년 03월 초중순부터 11월 말까지(기후에 따라 변동 가능)',
#  '물썰매장 : 6월~9월 <br /> 눈썰매장 : 12월~2월 <br />※ 기상상황에 따라 변동될 수 있음',
#  '연중',
#  '※ 비수기 - 주말 및 공휴일 실내운영<br>※ 준성수기(7/1~7/18,8/19~9/1) - 실내 및 실외운영(일부 실외시설 운영 제한)<br>※ 성수기(준성수기 기간을 제외한 7~8월) - 실내 및 실외운영',
#  '※ 비수기기간 : 11월~익년 4월',
#  '4월초~10월말',
#  '하계시즌 (5월 말~9월 초)<br>*공식 블로그 및 인스타 공지',
#  '365일 개장 (단 , 추석과 설날 휴무)',
#  '연중개방',
#  '봄 / 여름/ 가을',
#  '여름 성수기 운영(개장일 매년 다름)',
#  '여름',
#  '하절기 <br>※ 매년 상이함',
#  '5월~9월',
#  '동계시즌에만 오픈',
#  '봄,여름,가을',
#  '연중 무휴',
#  '성수기 7월 25일~8월 15일',
#  '동절기 눈썰매장 : 12월 중순 ~ 2월 중순 /하절기 물썰매장 : 6월 말 ~ 8월 중순',
#  '2019년',
#  '12월말~2월초',
#  '매년 7월, 8월',
#  '2022.12.22',
#  '상시개방',
#  '상시 (스노클링은 7~8월)',
#  '4월 ~ 10월',
#  '5~6월, 8~9월',
#  '여름,가을,겨울',
#  '5월 5일~9월 17일',
#  '봄, 여름, 가을, 겨울',
#  '2004년 ~ 현재',
#  '6월 ~ 10월 사이',
#  '경기 일정별 상이',
#  '매년 여름마다 한시적 운영',
#  '매년 7월~8월',
#  '봄,여름,가을,겨울',
#  '1월 말(2월) ~ 12월 초, 중순(날씨 상황에 따라 변경될 수 있습니다)',
#  '2018년 4월',
#  '연중개장(예약제)',
#  '7월~8월 말',
#  '매년 7.1~8.31(총 2개월)',
#  '매년 홈페이지 공지',
#  '3월 ~ 11월',
#  '3월~11월',
#  '4월~11월 (변동 가능)',
#  '2007년 9월',
#  '매년 05월 ~ 09월 2주차',
#  '매년 5월 말~9월 초<br>※ 매년 변동됨에 따라 홈페이지 또는 전화문의 요망',
#  '휴무일 이외에 연중 이용가능',
#  '년중 상시 운영',
#  '3월~12월 (매년 다름)',
#  '기후에 따라 변동 가능',
#  '12월 ~ 2월',
#  '2010년',
#  nan,
#  '카누 4월~11월<br />배낚시체험 3월~11월<br />요트 승선 체험 4월~11월 (연중 가능)',
#  '화요일~일요일',
#  '연중 개장',
#  '2011.06.13',
#  '상시개장',
#  '겨울철',
#  '5월~10월',
#  '연중개장',
#  '봄, 여름, 가을',
#  '래프팅 매년 하절기',
#  '봄, 가을',
#  '매년 3월1일~11월30일',
#  '상시이용 가능',
#  '3월~11월 (12~2월 휴장)',
#  '눈썰매장 : 12월 중순~2월 중순 / 물썰매장 6월 말~8월 중순',
#  '동절기 12월~2월, 하절기 3월~11월',
#  '상시 개장 (겨울엔 일정을 확인하고 방문)',
#  '2022.12.16~2023.02.12, 2023.12~2024.2 예정',
#  '야구 시즌 기간',
#  '여름,가을',
#  '365일(연중 무휴)',
#  '2012년 9월 10일 개장',
#  '봄, 여름',
#  '매년 6월 중 개장',
#  '2023년 5월26일~8월28일',
#  '여름 (7 ~ 8월만 운영)',
#  '매년 5월말~7월초, 9월',
#  '2019.01',
#  '4~10월',
#  '봄 / 가을(잔디썰매) : 3월~5월 / 9월~11월 <br>여름(물썰매) : 6월~8월 <br>겨울(눈썰매) : 12월~2월',
#  '화~일요일',
#  '봄, 여름, 가을 (12월~2월 동절기 운영중단)',
#  '여름 물썰매장, 야외풀장 : 7~8월<br>겨울 눈썰매장, 눈광장 : 12~2월',
#  '7월~8월 (여름 한시적 운영)',
#  '매년 3월하순 ~ 11월 초순',
#  '2020.4월',
#  '12월말 ~ 2월초',
#  '2월 ~ 12월 말',
#  '성수기운영 3.1~11.30, 비수기운영 12.1~익년 2.28',
#  '여름물썰매장 : 매년 6월 말, 7월 초 ~ 9월 초<br>겨울눈썰매장 : 매년 12월 초 ~ 약년 2월 말(약 90일)',
#  '여름, 가을, 겨울',
#  '4월~11월<br>※동절기(12월~3월) 폐쇄',
#  '3월 1일 ~ 추후 공지일까지',
#  '매년 3월 하순 ~ 11월 하순',
#  '7~8월(자세한 기간은 전화문의)',
#  '연중무휴 (우천시에도 정상운영)',
#  '3월~12월',
#  '스키장 리프트 개장일~폐장일',
#  '매일',
#  '봄, 가을, 겨울',
#  '수상레저 : 4~9월<br>핀란드 사우나 : 9~4월<br>ATV : 연중 이용가능',
#  '11월~3월',
#  '6월 24일~8월 20일',
#  '6월초~9월말',
#  '년중 운영',
#  '매년 4월 중순~10월 중순',
#  '연중무휴(기상에 따라 변동)',
#  '매주 수요일 휴무',
#  '연중 시즌별 변동',
#  '[고성 A코스] 운영기간 5.14~11.30<br>[고성 B코스] 한시적 미운영(운영기간 추후공지)<br>여름철 혹서미 및 장마기간 (7~8월)은 안전을 위해 임시중단 예정',
#  '유동적 운영',
#  '4~11월(동절기 폐쇄)',
#  '4월~10월',
#  '매년 3월~11월',
#  '5월 1일~8월 31일',
#  '00:00~24:00',
#  '[탑랜드]6월~8월<br>[번지점프]연중무휴, 단 사전예약',
#  '여름철 한시적 개장 (남양주시청 홈페이지 참고)',
#  '2009년 7월',
#  '3월 말 ~ 10월',
#  '4월~11월 (매년 변동됨에 따라 홈페이지 및 전화 문의 요망)',
#  '여름, 가을',
#  '00:00 ~ 24:00 (24시간 입장 가능)',
#  '2월 ~ 12월',
#  '매년 5월~10월<br>※ 단, 변동 가능성 있으므로 홈페이지 확인 요망',
#  '4월~11월',
#  '사계절 이용가능',
#  '2020.08.22~',
#  '365일',
#  '4월2일~10월31일 (성수기 7월17일~8월 15일)',
#  '상시',
#  '여름낚시 10월말까지 개장, 겨울 송어축제 12월말~1월 사이',
#  '봄~가을',
#  '봄,가을,겨울',
#  '실내수영장 : 정기휴장일을 제외한 날<br />실외수영장 : 매년7월초~8월말<br />(정확한 시기는 홈페이지 공지)',
#  '봄, 겨울',
#  '예약 시 문의',
#  '7~8월',
#  '겨울',
#  '연중무휴',
#  '겨울 시즌 개방 (2021년은 1.4 ~ 2.12일까지 운영)',
#  '2023.04.15~2023.10.31(매년 홈페이지 통해 공지)',
#  '2020. 02 월 프로그램 런칭',
#  '매년 6월 중순~8월 중순',
#  '동절기',
#  '매년 4월~10월',
#  '3월초~11월말 (봄~가을)',
#  '겨울시즌에만 운영 / 오픈일정 홈페이지 공지',
#  '3월~10월',
#  '휴관:동절기 잔디 구장(11월~3월/잔디 생육 및 관리를 위해 휴관)',
#  '매년 여름시즌 개장',
#  '상시 개장',
#  '하계시즌 (5월 말~9월 초)',
#  '매년 상이함 (홈페이지 공지)',
#  '5월 하순~9월 중순',
#  '6월 ~ 8월',
#  '2023.11.24~2024.03.03',
#  '5월 중순~8월 말까지 하절기 개장',
#  '봄, 여름, 가을 (4월~11월)',
#  '수상레저 5월~9월 / 롯지(숙박)와 실내외 수영장은 연중무휴',
#  '＊개장일 : 2008년 10월 15일',
#  '매년 12월15일~다음해 2월말',
#  '상시개장(단, 동절기에는 휴장, 12월~ 2월까지)',
#  '2018년 4월 18일',
#  '매년 7월 ~8월',
#  '수련활동 내용에 따라 상이',
#  '3월~11월 말 (기후에 따라 변동 가능)',
#  '첫 Tee-off 05:00 이후 / 마지막 Tee-off 19:30 이전',
#  '3~12월',
#  '봄,여름',
#  '홈페이지 참고',
#  '2017년 5월',
#  '12월 하순~2월 초순 (동절기) /  7~8월 (하절기)',
#  '2015년',
#  '부잔교 낚시터 : 매년 4월 1일~11월 마지막주 일요일<br>개매기장, 조개잡이 체험장 : 자연보호 계획에 따라 매년 6월~ 9월 중 2회~3회 행사',
#  '성수기 7월12일~8월22일 / 준성수기 6월25일~7월11일',
#  '상시 개방',
#  '상시 가능',
#  '봄,여름,겨울',
#  '없음']

# %%
import openai
import pandas as pd
import re
import json
import os
from tqdm import tqdm
from dotenv import load_dotenv

if not load_dotenv(dotenv_path="/home/hwang/projects/yanolja/src/.env"):
    print(".env 파일을 로드하지 못했습니다. 경로를 확인하세요.")
openai.api_key = os.getenv("OPENAI_API_KEY")
if openai.api_key is None:
    raise ValueError("OpenAI API 키가 설정되지 않았습니다. .env 파일을 확인하세요.")

df = tourapi

def preprocess_text(text):
    if pd.isna(text) or text.strip() == "":
        return "정보 없음"
    text = re.sub(r"<[^>]+>", " ", text)  
    text = re.sub(r"\s+", " ", text).strip()  
    return text

df["day_off"] = df["day_off"].apply(preprocess_text)
df["available_time"] = df["available_time"].apply(preprocess_text)
df["opening_period"] = df["opening_period"].apply(preprocess_text)

def transform_to_standard_format(day_off, available_time, opening_period):
    day_off = preprocess_text(str(day_off))
    available_time = preprocess_text(str(available_time))
    opening_period = preprocess_text(str(opening_period))
    
    prompt = f"""

    **입력 데이터**:
    - 영업기간(opening_period): {opening_period}
    - 영업시간(available_time): {available_time}
    - 휴무일(day_off): {day_off}

    입력 데이터에 대해서 이해한 바를 창조하지 말고 사실에 기반하여 서술하세요.
    """
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0125",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        temperature=0,
        max_tokens=500
    )
    content = response['choices'][0]['message']['content']
    return content


results = []
for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Processing rows"):
    transformed = transform_to_standard_format(row["day_off"], row["available_time"], row['opening_period'])
    results.append({"row_index": index, "transformed_data": transformed})

output_file = "transformed_tourapi_leisuresports_available_time_results_v1.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print(f"변환된 결과가 {output_file} 파일에 저장되었습니다.")
# Out:
# Processing rows: 100%|██████████| 4651/4651 [2:27:22<00:00,  1.90s/it]
# 변환된 결과가 transformed_tourapi_leisuresports_available_time_results_v1.json 파일에 저장되었습니다.

# %%
import json
import openai

import os
from dotenv import load_dotenv

from tqdm import tqdm

load_dotenv(dotenv_path="/home/hwang/projects/yanolja/src/.env")
openai.api_key = os.getenv("OPENAI_API_KEY")

input_file = "/home/hwang/projects/yanolja/src/collecting_data/data_analysis/transformed_tourapi_leisuresports_available_time_results_v1.json"
output_file = "transformed_tourapi_leisuresports_available_time_results_v2.json"

def transform_data_with_gpt(input_text):
    system_prompt = (
        "You are an assistant that transforms text about business hours and holidays into a structured JSON format. "
        "The JSON must strictly adhere to the following rules and reflect only the information explicitly provided in the input text. "
        "If the input specifies different 'entry closing time' (e.g., last entry allowed) and 'closing time' (e.g., business hours end), these must be clearly separated:\n\n"
        "Rules for transformation:\n"
        "1. The 'hours' key should only include the official business hours for each day (Monday to Sunday).\n"
        "   - If no business hours are provided for a specific day, leave that day as an empty list (e.g., \"Monday\": []).\n"
        "   - 'Closing time' refers to the time when the business officially stops operating and should be used in the 'hours' key.\n\n"
        "2. The 'special_conditions' key should include:\n"
        "   - 'entry closing time' (last entry allowed) as a separate condition with 'type: \"entry_closing_time\"' if explicitly stated.\n"
        "   - Any holidays, seasonal hours, or other exceptions.\n"
        "   - Each entry must have a 'type' and 'details'.\n\n"
        "3. If conflicting or ambiguous information is present in the input, separate the conflicting details into individual entries in 'special_conditions'.\n\n"
        "4. Do not infer or assume any information. Only use the data explicitly provided in the input text.\n"
        "   - If any information is missing or incomplete, leave the corresponding field empty (e.g., `[]`, `{}`).\n"
        "   - Only add 'details: \"Information not provided\"' if explicitly mentioned in the input text."
    )

    user_prompt = (
        f"Transform the following text into the required JSON format. "
        "Ensure that the output strictly adheres to the rules provided and includes only the information explicitly stated in the input text. "
        "If entry closing time (last entry allowed) and closing time (business end) are mentioned, clearly separate them. "
        "Add entry closing time as a 'special_condition' with 'type: \"entry_closing_time\"'. "
        "If information is missing, ambiguous, or incomplete, leave fields empty (e.g., `[]`, `{}`) and do not make assumptions:\n\n"
        f"Text: {input_text}\n\n"
        "Output example:\n"
        "{\n"
        '  "hours": {\n'
        '    "Monday": [],\n'
        '    "Tuesday": [{"start": "10:00", "end": "18:00"}],\n'
        '    "Wednesday": [{"start": "10:00", "end": "18:00"}],\n'
        '    "Thursday": [{"start": "10:00", "end": "18:00"}],\n'
        '    "Friday": [{"start": "10:00", "end": "18:00"}],\n'
        '    "Saturday": [{"start": "10:00", "end": "18:00"}],\n'
        '    "Sunday": [{"start": "10:00", "end": "18:00"}]\n'
        "  },\n"
        '  "special_conditions": [\n'
        '    {"type": "holiday", "details": "Closed on public holidays"},\n'
        '    {"type": "holiday", "details": "Closed on New Year\'s Day"},\n'
        '    {"type": "holiday", "details": "Closed on Lunar New Year and Chuseok"},\n'
        '    {"type": "entry_closing_time", "details": "Entry closes at 17:30 every day"}\n'
        "  ]\n"
        "}"
    )

    
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0125",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        temperature=0
    )
    
    return response["choices"][0]["message"]["content"]

with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

transformed_data = []

for item in tqdm(data):
    try:
        input_text = item.get("transformed_data", "")
        transformed_json = transform_data_with_gpt(input_text)  
        transformed_data.append({
            "row_index": item["row_index"],
            "transformed_data": json.loads(transformed_json)  
        })
    except Exception as e:
        print(f"Error processing row_index {item['row_index']}: {e}")

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(transformed_data, f, ensure_ascii=False, indent=4)

print(f"Transformed data saved to {output_file}")
# Out:
# 100%|██████████| 4651/4651 [2:41:49<00:00,  2.09s/it]
# Transformed data saved to transformed_tourapi_leisuresports_available_time_results_v2.json

# %%
file_path = "/home/hwang/projects/yanolja/src/collecting_data/data_analysis/transformed_tourapi_leisuresports_available_time_results_v2.json"

with open(file_path, 'r', encoding='utf-8') as f:
    at = json.load(f)

available_time = pd.DataFrame(at)

tourapi = pd.concat([tourapi, available_time], axis=1)

tourapi.rename(columns={'transformed_data': 'available_time_v2'}, inplace=True)

# %%
tourapi[((tourapi['latitude'] <= 33) | (tourapi['latitude'] >= 43)) & ((tourapi['longitude'] <= 124) | (tourapi['longitude'] >= 132))]
# Out:
#        source        category place_name              address  latitude  \
# 4378  tourAPI  leisure_sports      슈터스클럽  서울 강남구 강남대로96길 5 1층       0.0
#
#       longitude available_time                         parking  \
# 4378        0.0    12:00~20:00  13세 이상 13세 이하의 어린이는 보호자 동반이 필수
#
#                                             description  zip_code  ...  fee  \
# 4378  슈터스클럽은 저렴한 가격으로 도심에서 사격을 할 수 있는 실내 사격장이다. 140평...       NaN  ...  NaN
#
#      parking_fee age_available opening_period stroller  pet credit_card  \
# 4378          있음           NaN          정보 없음      NaN  NaN         NaN
#
#      details row_index                                  available_time_v2
# 4378     NaN      4378  {'hours': {'Monday': [], 'Tuesday': [{'start':...
#
# [1 rows x 26 columns]

# %%
from dotenv import load_dotenv
import os
import numpy as np

import importlib
import analysis_utils as analysis_utils 
importlib.reload(analysis_utils)

from analysis_utils import get_geocode

load_dotenv()

client_id = os.getenv("naver_geocoding_client_id")
client_secret = os.getenv("naver_geocoding_client_secret")

# query = "서울특별시 강남구 가로수길 69 엘큐브elcube"

# geocode = get_geocode(query=query, client_id=client_id, client_secret=client_secret)
# geocode

query = tourapi.iloc[4378]['address']
geocode = get_geocode(query=query, client_id=client_id, client_secret=client_secret)

tourapi.loc[4378, 'latitude'] = np.float64(geocode['latitude'])
tourapi.loc[4378, 'longitude'] = np.float64(geocode['longitude'])

# %%
tourapi[((tourapi['latitude'] <= 33) | (tourapi['latitude'] >= 43)) & ((tourapi['longitude'] <= 124) | (tourapi['longitude'] >= 132))]
# Out:
# Empty DataFrame
# Columns: [source, category, place_name, address, latitude, longitude, available_time, parking, description, zip_code, manager, phone, guidance, scale, capacity, day_off, fee, parking_fee, age_available, opening_period, stroller, pet, credit_card, details, row_index, available_time_v2]
# Index: []
#
# [0 rows x 26 columns]

# %%
tourapi[tourapi['address'].isnull()]
# Out:
#       source        category place_name address   latitude   longitude  \
# 515  tourAPI  leisure_sports      네스트캠핑     NaN  37.936371  127.541226
#
#      available_time parking  \
# 515  15:00~익일 11:00     NaN
#
#                                            description  zip_code  ...  fee  \
# 515  네스트 캠핑장은 경기도 가평군 북면 화악 2리 유촌교 인근에 위치하고 있다. 캠핑장...       NaN  ...  NaN
#
#     parking_fee                                      age_available  \
# 515          가능  <a href="http://rsvt.co.kr/reservation/reser_c...
#
#     opening_period stroller  pet credit_card  \
# 515        봄,여름,가을       없음  NaN          없음
#
#                                                details row_index  \
# 515  대여안내:릴선,화로대\n\n이용요금:45,000원~200,000원\n<br/>※ 이...       515
#
#                                      available_time_v2
# 515  {'hours': {'Monday': [], 'Tuesday': [{'start':...
#
# [1 rows x 26 columns]

# %%
from dotenv import load_dotenv
import os
import numpy as np

import importlib
import analysis_utils as analysis_utils
importlib.reload(analysis_utils)

from analysis_utils import get_reverse_geocode

load_dotenv()

client_id = os.getenv("naver_geocoding_client_id")
client_secret = os.getenv("naver_geocoding_client_secret")

# latitude = 37.472404
# longitude = 126.634438

# reverse_geocode = get_reverse_geocode(latitude=latitude, longitude=longitude, client_id=client_id, client_secret=client_secret)
# reverse_geocode

latitude, longitude = tourapi.loc[515, ['latitude', 'longitude']]
reverse_geocode = get_reverse_geocode(latitude=latitude, longitude=longitude, client_id=client_id, client_secret=client_secret)

tourapi.loc[515, 'address'] = reverse_geocode['address'].strip()

# %%
tourapi[tourapi['address'].isnull()]
# Out:
# Empty DataFrame
# Columns: [source, category, place_name, address, latitude, longitude, available_time, parking, description, zip_code, manager, phone, guidance, scale, capacity, day_off, fee, parking_fee, age_available, opening_period, stroller, pet, credit_card, details, row_index, available_time_v2]
# Index: []
#
# [0 rows x 26 columns]

# %%
# tourapi = tourapi.dropna(subset=['address'])

# %%
tourapi[tourapi['description'].isnull()]
# Out:
#        source        category         place_name  \
# 2412  tourAPI  leisure_sports  단양 패러글라이딩 패러는 내친구
# 2611  tourAPI  leisure_sports            청주실내수영장
# 3761  tourAPI  leisure_sports               봄봄캠핑
# 3822  tourAPI  leisure_sports        원동자연휴양림 야영장
# 3823  tourAPI  leisure_sports    굿뜨래웰빙마을 글램핑(일반)
# 4024  tourAPI  leisure_sports           안동시 월령빠지
# 4025  tourAPI  leisure_sports              안산자락길
#
#                                   address   latitude   longitude  \
# 2412              충청북도 단양군 가곡면 두산길 196-52  36.996729  128.396957
# 2611            충청북도 청주시 서원구 흥덕로 61 (사직동)  36.640795  127.472077
# 3761                강원특별자치도 춘천시 화악지암길 576  37.980160  127.620564
# 3822                  경상남도 양산시 원동면 늘밭로 64  35.398854  128.934879
# 3823                  충청남도 부여군 부여읍 가탑로 75  36.275616  126.930577
# 4024               경상북도 안동시 석주로 202 (상아동)  36.577457  128.758528
# 4025  서울특별시 서대문구 봉원사길 75-66 (봉원동)봉원동 산2-1  37.571245  126.946268
#
#                                          available_time parking description  \
# 2412             봄·여름 : 10:00~18:00 가을·겨울 : 10:00~16:00  5세~80세         NaN
# 2611  평일 05:30~11:50 / 13:20~20:20 주말 08:00~11:50 / ...     NaN         NaN
# 3761                                             예약시 문의     NaN         NaN
# 3822                                   12:00 ~ 익일 11:00     NaN         NaN
# 3823                                   15:00 ~ 익일 11:00     NaN         NaN
# 4024                                              정보 없음     NaN         NaN
# 4025                                              정보 없음     NaN         NaN
#
#       zip_code  ...                                                fee  \
# 2412   27021.0  ...                                                NaN
# 2611   28559.0  ...                                                NaN
# 3761   24200.0  ...                                                NaN
# 3822   50585.0  ...                                                NaN
# 3823   33160.0  ...                                                NaN
# 4024   36611.0  ...  도넛전동보트5인 3만원\n애그보트 4인 3만원12인\n파티보트 기본 5만원(추가요금있음)
# 4025    3721.0  ...                                                NaN
#
#        parking_fee                                      age_available  \
# 2412            있음                            홈페이지 접수전 전화예약 필수 (일정조정)
# 2611            있음                                                NaN
# 3761           NaN                                                NaN
# 3822          주차가능                                               전화예약
# 3823          주차가능  <a href="http://glamping-korea.com/accommodati...
# 4024  월령교주차 약 100대                                                NaN
# 4025           NaN                                                NaN
#
#      opening_period stroller  pet credit_card  \
# 2412          정보 없음      NaN  NaN         NaN
# 2611          정보 없음      NaN  NaN         NaN
# 3761          정보 없음      NaN  NaN         NaN
# 3822     봄,여름,가을,겨울       없음   가능          없음
# 3823  봄, 여름, 가을, 겨울       없음   불가          없음
# 4024          정보 없음      NaN  NaN         NaN
# 4025          정보 없음      NaN  NaN         NaN
#
#                                                 details row_index  \
# 2412                                                NaN      2412
# 2611                                                NaN      2611
# 3761  이용요금:50,000~70,000원\n*이용요금은 예약 시 문의\n부대시설:운동시설...      3761
# 3822  이용요금:30,000원 ~ 200,000원<br>※ 이용요금은 변동될 수 있으므로 ...      3822
# 3823  이용요금:90,000원~110,000원<br> ※ 이용요금은 변동될 수 있으므로 홈...      3823
# 4024                                                NaN      4024
# 4025                                                NaN      4025
#
#                                       available_time_v2
# 2412  {'hours': {'Monday': [], 'Tuesday': [{'start':...
# 2611  {'hours': {'Monday': [{'start': '05:30', 'end'...
# 3761  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 3822  {'hours': {'Monday': [], 'Tuesday': [{'start':...
# 3823  {'hours': {'Monday': [], 'Tuesday': [{'start':...
# 4024  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 4025  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
#
# [7 rows x 26 columns]

# %%
tourapi[tourapi['description'].isnull()]['place_name'].tolist()
# Out:
# ['단양 패러글라이딩 패러는 내친구',
#  '청주실내수영장',
#  '봄봄캠핑',
#  '원동자연휴양림 야영장',
#  '굿뜨래웰빙마을 글램핑(일반)',
#  '안동시 월령빠지',
#  '안산자락길']

# %%
# 단양 패러글라이딩 패러는 내친구 - 소개 없음
tourapi.loc[tourapi['place_name'] == '청주실내수영장'] = "청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다"
tourapi.loc[tourapi['place_name'] == '봄봄캠핑'] = "강원도 춘천시에 위치한 봄봄캠핑이다. 저희 봄봄캠핑은 편안하고 안락한 캠핑을 지향하는 곳으로 총 12개의 여유로운 파쇄석 사이트가 있으며 개별화장실(단독사이트 편의시설=샤워실+세면실+개수대)을 갖추고 있다. 캠핑을 좋아하시는 캠퍼들의 멋진 추억을 만들어 드리기 위해 더욱 더 노력한다. 낭만의 도시 춘천! 춘천여행의 동반자 봄봄캠핑!"
tourapi.loc[tourapi['place_name'] == '원동자연휴양림 야영장'] = "원동자연휴양림은 영남의 알프스라 불리는 가지산, 영축산, 신불산, 천태산, 토곡산, 오봉산 등에 둘러싸인 고즈넉한 곳에 위치하고 있다. 토곡산(855m) 동단 능선부로부터 휴양림을 거쳐 서단으로 통하는 계곡의 풍부한 수계와 울창한 숲, 그리고 물풍지폭포 등이 장관이며, 기암괴석과 계곡의 맑은 물을 따라 산림욕을 즐기며 산행할 수 있다. 토곡산 정상에 오르면 굽이굽이 흐르는 영남의 젖줄 낙동강의 아름다움을 감상할 수 있어, 도시생활의 스트레스를 말끔히 씻을 수 있다. 심산유곡을 관망할 수 있는 전망대의 계절별 전망과 통나무로 만든 산막, 새소리가 들려오는 계곡에서 자연산 표고버섯을 맛보며 무릉도원이 따로 없는 숲 속 정취를 즐길 수 있다 아름다운 자연 속에 자리하고 있어 수량이 풍부하고 물이 맑기로 소문난 캠핑장이다. 인근에는 천태산과 배내골 등의 여러 산과 계곡들이 아름답게 조화를 이루고 있어 피로에 지친 그대의 편안한 휴식공간이자 다정한 벗이 되고 있는 자연의 낙원이라 할 수 있다."
tourapi.loc[tourapi['place_name'] == '굿뜨래웰빙마을 글램핑(일반)'] = "캠핑을 좋아하지만 캠핑 장비를 갖추기 어려울 때, 특별한 휴가를 즐기고 싶을 때 굿뜨래 웰빙마을에서 즐기기 좋다. 글램핑장 주변으로 산이 병풍처럼 둘러져 있어 산책하기에 좋고 족구장, 농구장, 물놀이장(7~8월 운영)이 있어 간단한 레포츠 활동을 즐길 수 있다. 또한 야외테이블은 물론 개인 바비큐 시설과 내부에는 TV, 침대, 싱크대, 화장실 등이 마련되어 있고 인덕션, 압력밥솥 등의 물품들이 구비되어 있어 편하게 취사를 하실 수 있다. 부여 굿뜨래 웰빙마을, 123년 동안 백제의 왕도였던 부여는 천 년 세월이 깃든 역사의 보물창고로 우리나라 대표적인 역사문화 관광지다. 검소하지만 누추하지 않은 백제문화를 대변하듯 옛 왕도의 기품이 스며들어 있다. 유네스코 세계유산에 등재된 관북리 유적과 부소산성, 정림사지, 능산리고분, 나성을 비롯해 천만송이 연꽃으로 채워진 궁남지, 사진작가들에게 많은 사랑을 받고 있는 성흥산 사랑나무, 드라마 촬영지로 유명한 서동요 테마파크, 국립 부여박물관, 백제 문화단지 등 지붕 없는 박물관이라는 명성에 걸맞게 볼거리로 가득하다."
# 안동시 월령빠지 - 소개 없음
tourapi.loc[tourapi['place_name'] == '안산자락길'] = "안산자락길은 서울 서대문구에 있는 7km 길이의 순환형 무장애 자락길로, 장애인, 노약자, 어린이 등 보행약자도 쉽게 숲을 즐길 수 있다."
# Out:
# /tmp/ipykernel_40255/2530175951.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tourapi.loc[tourapi['place_name'] == '청주실내수영장'] = "청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다"
# /tmp/ipykernel_40255/2530175951.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tourapi.loc[tourapi['place_name'] == '청주실내수영장'] = "청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다"
# /tmp/ipykernel_40255/2530175951.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tourapi.loc[tourapi['place_name'] == '청주실내수영장'] = "청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다"
# /tmp/ipykernel_40255/2530175951.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tourapi.loc[tourapi['place_name'] == '청주실내수영장'] = "청주실내수영장은 충청북도 청주시 서원구 사직동에 위치한 실내수영장으로, 다음과 같은 특징이 있다. 길이 20m, 수심 1.2m, 3개의 레인을 보유하고 있다. 항상 29~30도의 수온을 유지하고 있다. 다층여과 방식의 자동정수기능으로 최적의 수질을 유지하고 있다. 따뜻한 온수풀에서 휴식을 취할 수 있다"

# %%
import importlib
import analysis_utils as analysis_utils
importlib.reload(analysis_utils)

from analysis_utils import get_wikipedia_summary

tourist_spot = "잠월미술관"
summary = get_wikipedia_summary(tourist_spot)

# %%
tourapi[tourapi['parking'].isnull()]
# Out:
#        source        category               place_name  \
# 0     tourAPI  leisure_sports       [인천 개항 누리길] 2시간 코스
# 1     tourAPI  leisure_sports  [강화 나들길 제3코스] 고려왕릉 가는 길
# 2     tourAPI  leisure_sports         [시흥 늠내길 제1코스] 숲길
# 3     tourAPI  leisure_sports         [시흥 늠내길 제3코스] 옛길
# 4     tourAPI  leisure_sports          평화누리길 4코스 행주나루길
# ...       ...             ...                      ...
# 4646  tourAPI  leisure_sports                 하영올레 3코스
# 4647  tourAPI  leisure_sports                    한강레포츠
# 4648  tourAPI  leisure_sports               아시아나 컨트리클럽
# 4649  tourAPI  leisure_sports                요트투어 샹그릴라
# 4650  tourAPI  leisure_sports                   유니밸리CC
#
#                              address   latitude   longitude  \
# 0       인천광역시 중구 제물량로218번길 3 (해안동1가)  37.472606  126.620501
# 1              인천광역시 강화군 강화읍 청하동길 24  37.745825  126.482261
# 2                   경기도 시흥시 시청로(장현동)  37.380131  126.802989
# 3                   경기도 시흥시 대야동(대야동)  37.455797   126.78743
# 4       경기도 고양시 덕양구 행주로15번길 89(행주외동)   37.59612   126.82647
# ...                              ...        ...         ...
# 4646  제주특별자치도 서귀포시  중앙로 (105, 서귀포시청)  33.253953  126.559798
# 4647        경기도 남양주시 화도읍 먹갓로 54(화도읍)  37.658846  127.274225
# 4648         경기도 용인시 처인구 양지면 양대로 290   37.25476  127.292687
# 4649       제주특별자치도 서귀포시 중문관광로 154-17  33.245068   126.41561
# 4650           경상북도 고령군 대가야읍 일량로 588  35.681577  128.293922
#
#                                          available_time parking  \
# 0     매주 화~일요일 (10:00 ~ 17:00) ※ 해설안내는 예약이 필수이며 상황에 ...     NaN
# 1                                                 정보 없음     NaN
# 2                                                 정보 없음     NaN
# 3                                                 정보 없음     NaN
# 4                                                    상시     NaN
# ...                                                 ...     ...
# 4646                                              정보 없음     NaN
# 4647                                              정보 없음     NaN
# 4648                                              정보 없음     NaN
# 4649                                          ※ 전화문의 요망     NaN
# 4650                                              정보 없음     NaN
#
#                                             description zip_code  ...  fee  \
# 0     인천역 부근 개항장 일대에 조성된 인천 개항 누리길은 근대 개항기 역사와 문화를 체...  22314.0  ...   무료
# 1     강화나들길은 해안을 따라 1.3km마다 자리한 돈대와 강화산성, 고려왕릉을 돌며 강...  23033.0  ...  NaN
# 2     [시흥 늠내길 제1코스] 숲길은 높지 않지만, 숲과 나무들이 조화롭게 어우러진 산봉...  14998.0  ...  NaN
# 3     ‘시흥 늠내길 제3코스 옛길’은 산자락과 산자락을 이어 만든 길이며, 길을 걷다 보...  14901.0  ...  NaN
# 4     경기북부 DMZ 인근 지역은 한국전쟁의 아픈 역사와 온 국민의 통일 염원을 간직한 ...  10440.0  ...  NaN
# ...                                                 ...      ...  ...  ...
# 4646  하영올레는 서귀포시의 원도심의 매력을 듬뿍 느낄 수 있는 도보코스이다. 총 3개의 ...  63584.0  ...  NaN
# 4647  2006년도 12월에 문을 연 한강레포츠는 모든 장비가 신형이고, 고객들 개인에게 ...  12157.0  ...  NaN
# 4648  아시아나 컨트리클럽은 전통 컨트리클럽의 모든 것을 이어 받은 67만여 평의 대자연 ...  17155.0  ...  NaN
# 4649  여러 미디어에서 앞다투어 소개되는 제주 최고의 요트투어 업체로서 제주 제일의 해안 ...  63535.0  ...  NaN
# 4650  고령 유니밸리CC는 대구 화원IC에서 20분 거리에 위치하고 있으며 풍수지리학상으로...  40143.0  ...  NaN
#
#      parking_fee                                      age_available  \
# 0             가능  ＊문화관광해설사(10명 이상, 사전 예약)<br />\n인천문화관광해설사회 예약문의...
# 1             있음                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4             가능                                                NaN
# ...          ...                                                ...
# 4646         NaN                                                NaN
# 4647       주차 가능                                 전화 문의 031-591-3376
# 4648       주차 가능  전화 문의 031-330-1111~2 <br />\n홈페이지 <a href="htt...
# 4649        주차가능                                   퍼시픽 리솜 1544-2988
# 4650       주차 가능  인터넷예약 <a href="http://www.univalley.co.kr/" ta...
#
#      opening_period stroller  pet credit_card  \
# 0             정보 없음       없음  NaN          없음
# 1             정보 없음       없음  NaN          없음
# 2             정보 없음       없음  NaN          없음
# 3             정보 없음       없음  NaN          없음
# 4             정보 없음       없음  NaN          없음
# ...             ...      ...  ...         ...
# 4646          정보 없음      NaN  NaN         NaN
# 4647          정보 없음       없음   없음          가능
# 4648          정보 없음       없음   없음          없음
# 4649          정보 없음       불가   불가          가능
# 4650          정보 없음       없음   없음          없음
#
#                                                 details row_index  \
# 0                                                   NaN         0
# 1     코스안내:[강화 나들길 제3코스] 고려왕릉 가는 길<br />\n* 온수공영주차장-...         1
# 2     코스안내:[늠내길 제1코스 숲길]\n- 출발 / 도착점 : 시흥시청\n- 소요시간 ...         2
# 3     코스안내:[늠내길 제3코스 옛길]<br>\n- 출발 / 도착점 : 시흥대야역 3번 ...         3
# 4     코스안내:[평화누리길 4코스] 행주나루길<br />\n* 길이 : 11km <br ...         4
# ...                                                 ...       ...
# 4646  코스안내:3코스는 서귀포시청 제1청사~솜반천탐방로~흙담소나무길~변시지그림공원~지장샘...      4646
# 4647     부대시설:탈의실\n보유장비:스키,블레이드,보드,스키복,스키부츠,보드부츠,고글,폴\n      4647
# 4648  코스안내:* 동코스 - 18홀 72파 / 6,800yd<br /> \n웅장하고 변화...      4648
# 4649  체험프로그램:퍼블릭투어, 프라이빗투어, 썬라이즈 투어, 요트프로포즈, 제트보트 등\...      4649
# 4650  코스안내:정규 대중 골프장 9홀 36파\n이용요금:* 주중<br />\n18홀 : ...      4650
#
#                                       available_time_v2
# 0     {'hours': {'Monday': [], 'Tuesday': [{'start':...
# 1     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 2     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 3     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 4     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# ...                                                 ...
# 4646  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 4647  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 4648  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 4649  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
# 4650  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...
#
# [4268 rows x 26 columns]

# %%
import pandas as pd

parking = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/etc/전국주차장정보표준데이터-20241210.xls")
parking.columns = parking.iloc[0]
parking = parking[1:].reset_index(drop=True)
parking['위도'] = pd.to_numeric(parking['위도'], errors="coerce")
parking['경도'] = pd.to_numeric(parking['경도'], errors="coerce")
parking = parking.dropna(subset=['위도', '경도'])

# %%
parking.head(2)
# Out:
# 0       주차장관리번호  주차장명 주차장구분 주차장유형               소재지도로명주소 소재지지번주소 주차구획수 급지구분  \
# 0  204-2-000023  아래숯골    공영    노외  경기도 성남시 수정구 성남대로 1259     NaN   150    1
# 1  204-2-000024  태평4동    공영    노외    경기도 성남시 수정구 태평로 109     NaN    89    1
#
# 0 부제시행구분        운영요일  ...  결제방법                 특기사항           관리기관명 전화번호  \
# 0    요일제  평일+토요일+공휴일  ...  신용카드  경차+장애인 차량 50프로 할인 등  성남도시개발공사 노외주차처  NaN
# 1    요일제  평일+토요일+공휴일  ...  신용카드  경차+장애인 차량 50프로 할인 등  성남도시개발공사 노외주차처  NaN
#
# 0         위도          경도 장애인전용주차구역보유여부     데이터기준일자   제공기관코드    제공기관명
# 0  37.442288  127.126662             Y  2024-05-31  3780000  경기도 성남시
# 1  37.451234  127.138580             Y  2024-05-31  3780000  경기도 성남시
#
# [2 rows x 34 columns]

# %%
import importlib
import analysis_utils as analysis_utils
importlib.reload(analysis_utils)

from analysis_utils import find_nearest_parking

nearest_parking = find_nearest_parking(poi_lat=37.610198, poi_lon=127.040989, parking_data=parking)

# %%
nearest_parking
# Out:
# '동방고개 공영 주차장'

# %%
import pandas as pd
import numpy as np

def combine_columns(row):
    additional_info = []

    # fee 추가
    if pd.notna(row['fee']):
        additional_info.append(f"요금: {row['fee']}")
    
    # stroller 추가
    if pd.notna(row['stroller']):
        additional_info.append(f"유모차: {row['stroller']}")
    
    # pet 추가
    if pd.notna(row['pet']):
        additional_info.append(f"반려동물: {row['pet']}")

    # age_available 추가
    if pd.notna(row['age_available']):
        additional_info.append(f"체험가능연령: {row['age_available']}")
    
    details = row['details'] if pd.notna(row['details']) else ""
    
    combined_details = details + ('\n' if details and additional_info else '') + '\n'.join(additional_info)
    return combined_details

tourapi['details'] = tourapi.apply(combine_columns, axis=1)

tourapi = tourapi.drop(columns=['fee', 'stroller', 'pet', 'age_available'])

# %%
tourapi['source'] = 'tourAPI'
tourapi['category'] = 'leisure_sports'

# %%
tourapi = tourapi[['source','category', 'place_name', 'address', 'latitude', 'longitude', 'available_time', 'available_time_v2', 'parking', 'description', 'details']]

# %%
tourapi
# Out:
#        source        category               place_name  \
# 0     tourAPI  leisure_sports       [인천 개항 누리길] 2시간 코스
# 1     tourAPI  leisure_sports  [강화 나들길 제3코스] 고려왕릉 가는 길
# 2     tourAPI  leisure_sports         [시흥 늠내길 제1코스] 숲길
# 3     tourAPI  leisure_sports         [시흥 늠내길 제3코스] 옛길
# 4     tourAPI  leisure_sports          평화누리길 4코스 행주나루길
# ...       ...             ...                      ...
# 4646  tourAPI  leisure_sports                 하영올레 3코스
# 4647  tourAPI  leisure_sports                    한강레포츠
# 4648  tourAPI  leisure_sports               아시아나 컨트리클럽
# 4649  tourAPI  leisure_sports                요트투어 샹그릴라
# 4650  tourAPI  leisure_sports                   유니밸리CC
#
#                              address   latitude   longitude  \
# 0       인천광역시 중구 제물량로218번길 3 (해안동1가)  37.472606  126.620501
# 1              인천광역시 강화군 강화읍 청하동길 24  37.745825  126.482261
# 2                   경기도 시흥시 시청로(장현동)  37.380131  126.802989
# 3                   경기도 시흥시 대야동(대야동)  37.455797   126.78743
# 4       경기도 고양시 덕양구 행주로15번길 89(행주외동)   37.59612   126.82647
# ...                              ...        ...         ...
# 4646  제주특별자치도 서귀포시  중앙로 (105, 서귀포시청)  33.253953  126.559798
# 4647        경기도 남양주시 화도읍 먹갓로 54(화도읍)  37.658846  127.274225
# 4648         경기도 용인시 처인구 양지면 양대로 290   37.25476  127.292687
# 4649       제주특별자치도 서귀포시 중문관광로 154-17  33.245068   126.41561
# 4650           경상북도 고령군 대가야읍 일량로 588  35.681577  128.293922
#
#                                          available_time  \
# 0     매주 화~일요일 (10:00 ~ 17:00) ※ 해설안내는 예약이 필수이며 상황에 ...
# 1                                                 정보 없음
# 2                                                 정보 없음
# 3                                                 정보 없음
# 4                                                    상시
# ...                                                 ...
# 4646                                              정보 없음
# 4647                                              정보 없음
# 4648                                              정보 없음
# 4649                                          ※ 전화문의 요망
# 4650                                              정보 없음
#
#                                       available_time_v2 parking  \
# 0     {'hours': {'Monday': [], 'Tuesday': [{'start':...     NaN
# 1     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 2     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 3     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 4     {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# ...                                                 ...     ...
# 4646  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 4647  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 4648  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 4649  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
# 4650  {'hours': {'Monday': [], 'Tuesday': [], 'Wedne...     NaN
#
#                                             description  \
# 0     인천역 부근 개항장 일대에 조성된 인천 개항 누리길은 근대 개항기 역사와 문화를 체...
# 1     강화나들길은 해안을 따라 1.3km마다 자리한 돈대와 강화산성, 고려왕릉을 돌며 강...
# 2     [시흥 늠내길 제1코스] 숲길은 높지 않지만, 숲과 나무들이 조화롭게 어우러진 산봉...
# 3     ‘시흥 늠내길 제3코스 옛길’은 산자락과 산자락을 이어 만든 길이며, 길을 걷다 보...
# 4     경기북부 DMZ 인근 지역은 한국전쟁의 아픈 역사와 온 국민의 통일 염원을 간직한 ...
# ...                                                 ...
# 4646  하영올레는 서귀포시의 원도심의 매력을 듬뿍 느낄 수 있는 도보코스이다. 총 3개의 ...
# 4647  2006년도 12월에 문을 연 한강레포츠는 모든 장비가 신형이고, 고객들 개인에게 ...
# 4648  아시아나 컨트리클럽은 전통 컨트리클럽의 모든 것을 이어 받은 67만여 평의 대자연 ...
# 4649  여러 미디어에서 앞다투어 소개되는 제주 최고의 요트투어 업체로서 제주 제일의 해안 ...
# 4650  고령 유니밸리CC는 대구 화원IC에서 20분 거리에 위치하고 있으며 풍수지리학상으로...
#
#                                                 details
# 0     요금: 무료\n유모차: 없음\n체험가능연령: ＊문화관광해설사(10명 이상, 사전 예...
# 1     코스안내:[강화 나들길 제3코스] 고려왕릉 가는 길<br />\n* 온수공영주차장-...
# 2     코스안내:[늠내길 제1코스 숲길]\n- 출발 / 도착점 : 시흥시청\n- 소요시간 ...
# 3     코스안내:[늠내길 제3코스 옛길]<br>\n- 출발 / 도착점 : 시흥대야역 3번 ...
# 4     코스안내:[평화누리길 4코스] 행주나루길<br />\n* 길이 : 11km <br ...
# ...                                                 ...
# 4646  코스안내:3코스는 서귀포시청 제1청사~솜반천탐방로~흙담소나무길~변시지그림공원~지장샘...
# 4647  부대시설:탈의실\n보유장비:스키,블레이드,보드,스키복,스키부츠,보드부츠,고글,폴\n...
# 4648  코스안내:* 동코스 - 18홀 72파 / 6,800yd<br /> \n웅장하고 변화...
# 4649  체험프로그램:퍼블릭투어, 프라이빗투어, 썬라이즈 투어, 요트프로포즈, 제트보트 등\...
# 4650  코스안내:정규 대중 골프장 9홀 36파\n이용요금:* 주중<br />\n18홀 : ...
#
# [4651 rows x 11 columns]
