# %%
import os
import glob
import pandas as pd

folder_path = "/home/hwang/projects/yanolja/data/dataset/tourAPI"
files = glob.glob(os.path.join(folder_path, '*.xls'))

col_info = {}
for file in files:
    df = pd.read_excel(file)
    file_name = os.path.basename(file)
    col_info[file_name] = df.columns.tolist()

# %%
col_info.keys()
# Out:
# dict_keys(['thingsToEnjoy.xls', 'leisureSports.xls', 'touristAttractions.xls', 'restaurant.xls', 'culturalFacilities.xls', 'lodgment.xls', 'shopping.xls', 'traffic.xls'])

# %%
fns = [set(col_info[fn]) for fn in col_info.keys()]

# %%
set.intersection(*fns)
# Out:
# {'개요', '경도', '관리자', '명칭', '우편번호', '위도', '전화번호', '주소'}

# %%
culture = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/culturalFacilities.xls")
leisure = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/leisureSports.xls")
lodgment = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/lodgment.xls")
restaurant = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/restaurant.xls")
shop = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/shopping.xls")
enjoy = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/thingsToEnjoy.xls")
attraction = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/touristAttractions.xls")
traffic = pd.read_excel("/home/hwang/projects/yanolja/data/dataset/tourAPI/traffic.xls")

culture.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '문의 및 안내', '규모',
#        '수용인원', '이용시간', '쉬는날', '이용요금', '할인정보', '관람소요시간', '주차시설', '주차요금',
#        '유모차 대여 여부', '애완동물 동반 가능 여부', '신용카드 가능 여부', '상세정보'],
#       dtype='object')

# %%
leisure.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '문의 및 안내', '규모',
#        '수용인원', '쉬는날', '개장기간', '이용시간', '입장료', '체험가능연령', '주차시설', '주차요금',
#        '유모차 대여 여부', '애완동물 동반 가능 여부', '신용카드 가능 여부', '상세정보'],
#       dtype='object')

# %%
lodgment.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '숙박 종류', '문의 및 안내',
#        '규모', '수용 가능 인원', '객실 수', '객실 유형', '주차 가능', '조리 가능', '체크인', '체크아웃',
#        '예약 안내', '예약안내 홈페이지', '픽업서비스', '식음료장', '부대 시설', '세미나', '스포츠시설', '사우나실',
#        '뷰티 시설', '노래방', '바베큐장', '캠프화이어', '자전거대여', '휘트니스센터', '공용 PC실', '공용 샤워실',
#        '상세정보', '환불규정'],
#       dtype='object')

# %%
restaurant.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '문의 및 안내', '규모',
#        '좌석수', '주차 시설', '어린이놀이방', '개업일', '영업시간', '쉬는날', '대표메뉴', '취급메뉴', '할인정보',
#        '금연/흡연', '신용카드정보', '포장가능', '예약안내', '상세정보', '인허가번호'],
#       dtype='object')

# %%
shop.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '문의 및 안내', '규모',
#        '판매품목', '품목별 가격', '장서는 날', '개장일', '영업시간', '쉬는날', '매장안내', '주차시설',
#        '문화센터 바로가기', '유모차 대여 여부', '애완동물 동반 가능 여부', '신용카드 가능 여부', '화장실', '상세정보'],
#       dtype='object')

# %%
enjoy.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', '주최자 정보',
#        '주최자 연락처', '주관사 정보', '주관사 연락처', '행사시작일', '행사종료일', '공연시간', '행사장소',
#        '이벤트 홈페이지', '이용요금', '할인정보', '관람소요시간', '관람가능연령', '예매처', '행사장 위치안내',
#        '부대행사', '프로그램', '상세정보', '진행형태', '축제형태'],
#       dtype='object')

# %%
attraction.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요', ' 유산구분', '문의 및 안내',
#        '개장일', '쉬는날', '체험안내', '체험가능연령', '수용인원', '이용시기', '이용시간', '주차시설',
#        '유모차 대여 여부', '애완동물 동반 가능 여부', '신용카드 가능 여부', '상세정보'],
#       dtype='object')

# %%
traffic.columns
# Out:
# Index(['명칭', '우편번호', '관리자', '전화번호', '주소', '위도', '경도', '개요'], dtype='object')

# %%
from collections import Counter

all_columns = [
    list(culture.columns),
    list(leisure.columns),
    list(lodgment.columns),
    list(restaurant.columns),
    list(shop.columns),
    list(enjoy.columns),
    list(attraction.columns),
    list(traffic.columns)
]

merged_columns = [column for columns in all_columns for column in columns]

column_counts = Counter(merged_columns)

column_usage_df = pd.DataFrame(column_counts.items(), columns=["Column Name", "File Count"])

column_usage_df = column_usage_df.sort_values(by="File Count", ascending=False)

column_usage_df.head(50)
# Out:
#       Column Name  File Count
# 0              명칭           8
# 1            우편번호           8
# 2             관리자           8
# 3            전화번호           8
# 4              주소           8
# 5              위도           8
# 6              경도           8
# 7              개요           8
# 21           상세정보           7
# 8         문의 및 안내           6
# 9              규모           5
# 12            쉬는날           5
# 20     신용카드 가능 여부           4
# 18      유모차 대여 여부           4
# 16           주차시설           4
# 19  애완동물 동반 가능 여부           4
# 14           할인정보           3
# 11           이용시간           3
# 10           수용인원           3
# 24         체험가능연령           2
# 65            개장일           2
# 17           주차요금           2
# 54           영업시간           2
# 15         관람소요시간           2
# 13           이용요금           2
# 70        주최자 연락처           1
# 68            화장실           1
# 67      문화센터 바로가기           1
# 66           매장안내           1
# 64          장서는 날           1
# ...

# %%
traffic.head()
# Out:
#                                            명칭   우편번호  관리자             전화번호  \
# 0      Incheon International Airport (인천국제공항)  22382  NaN    +82-1577-2600
# 1  Damyang Passenger Bus Terminal (담양공용버스터미널)  57344  NaN              NaN
# 2                 Yeosu Expo Station (여수엑스포역)  59723  NaN  +82-61-663-7788
# 3                     Chuncheon Station (춘천역)  24244  NaN              NaN
# 4                      Suncheon Station (순천역)  57964  NaN              NaN
#
#                                                   주소         위도          경도  \
# 0                  272 Gonghang-ro, Jung-gu, Incheon  37.448764  126.452733
# 1        24-1, Jungang-ro, Damyang-gun, Jeollanam-do  35.315149  126.984145
# 2             2, Mangyang-ro, Yeosu-si, Jeollanam-do  34.755294  127.748658
# 3          1, Pyeonghwa-ro, Chuncheon-si, Gangwon-do  37.884514  127.716617
# 4  135, Palma-ro, Suncheon-si, Jeollanam-do(Deoka...  34.946135  127.503447
#
#                                                   개요
# ...

# %%
attraction.head()
# Out:
#           명칭   우편번호  관리자 전화번호                          주소         위도  \
# 0    수성못 유원지  42202  NaN  NaN          대구광역시 수성구 용학로 35-5  35.826842
# 1       동락공원  39392  NaN  NaN     경상북도 구미시 3공단1로 191(진평동)  36.097116
# 2  연천 초성김치마을  11023  NaN  NaN         경기도 연천군 청산면 평화로 209  37.992731
# 3        명성산  11103  NaN  NaN             경기도 포천시 이동면 도평리  38.095674
# 4    포천 산정호수  11103  NaN  NaN  경기도 포천시 영북면 산정호수로411번길 104  38.068838
#
#            경도                                                 개요  유산구분  \
# 0  128.612873  수성유원지는 범물동 용지봉(629ｍ)에서 북서부로 뻗어 내린 줄기의 하부에 위치하여...   NaN
# 1  128.401951  낙동강을 따라 구미대교 아래 임수동에서 칠곡군 석적읍 중리까지 이르는 수변형 도시공...   NaN
# 2  127.069412  경원선 초성리역∙열두개울 부근에 있는 연천 초성김치마을은 김치를 테마로 한 체험 마...   NaN
# 3  127.350422  가을철이면 억새산행 대상지로 유명한 산이다. 서울에서 동북으로 84km, 운천에서 ...   NaN
# 4  127.322103  포천시의 북쪽 강원도 철원군과 도계에 있는 명성산(해발 923m)이 병풍처럼 둘러있...   NaN
#
#                                              문의 및 안내  ...  \
# 0    수성유원지 053-666-2863<br/>\n수성못 관광안내소 053-761-0645  ...
# ...
